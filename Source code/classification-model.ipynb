# %%
# !pip install facenet-pytorch
# Out:
# Collecting facenet-pytorch
#   Downloading facenet_pytorch-2.5.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 30.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from facenet-pytorch) (1.24.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from facenet-pytorch) (2.31.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from facenet-pytorch) (0.15.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from facenet-pytorch) (9.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->facenet-pytorch) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->facenet-pytorch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->facenet-pytorch) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->facenet-pytorch) (2023.11.17)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from torchvision->facenet-pytorch) (2.0.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (3.12.2)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (4.5.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch->torchvision->facenet-pytorch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch->torchvision->facenet-pytorch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch->torchvision->facenet-pytorch) (1.3.0)
# Installing collected packages: facenet-pytorch
# Successfully installed facenet-pytorch-2.5.3

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader 
import os
import cv2
import matplotlib.pyplot as plt
from IPython.display import FileLink
from sklearn.model_selection import train_test_split
from PIL import Image
from torchvision import models
from torchinfo import summary
from facenet_pytorch import InceptionResnetV1
from tqdm import tqdm
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import json
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df_detect = pd.read_csv("/kaggle/input/private-data-label80/data.csv",index_col = None)
df_detect.head()
# Out:
#    Unnamed: 0     file_name                   bbox
# 0           0   2435944.jpg   [795, 104, 669, 927]
# 1           1  13025961.jpg   [908, 281, 344, 359]
# 2           2  67202325.jpg  [1301, 197, 193, 247]
# 3           3   9800474.jpg   [934, 279, 285, 380]
# 4           4  66279849.jpg   [550, 298, 238, 328]

# %%
for i in range(len(df_detect)):
    file = df_detect.loc[i,"file_name"]
    img_path = os.path.join("/kaggle/input/80-test/data/",file)
    img = cv2.imread(img_path)
    x,y,w,h = eval(df_detect.loc[i,"bbox"])
    cv2.imwrite(str(i) + ".jpg",img[int(y) : int(y + h), int(x) : int(x + w)])

# %%
# !zip -r crop_image_80.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/1654.jpg (deflated 0%)
#   adding: kaggle/working/11981.jpg (deflated 0%)
#   adding: kaggle/working/7361.jpg (deflated 0%)
#   adding: kaggle/working/5626.jpg (deflated 1%)
#   adding: kaggle/working/2784.jpg (deflated 0%)
#   adding: kaggle/working/4505.jpg (deflated 1%)
#   adding: kaggle/working/12772.jpg (deflated 0%)
#   adding: kaggle/working/8545.jpg (deflated 0%)
#   adding: kaggle/working/651.jpg (deflated 1%)
#   adding: kaggle/working/12438.jpg (deflated 1%)
#   adding: kaggle/working/5134.jpg (deflated 0%)
#   adding: kaggle/working/13572.jpg (deflated 0%)
#   adding: kaggle/working/3476.jpg (deflated 0%)
#   adding: kaggle/working/2523.jpg (deflated 0%)
#   adding: kaggle/working/3301.jpg (deflated 0%)
#   adding: kaggle/working/10474.jpg (deflated 1%)
#   adding: kaggle/working/4384.jpg (deflated 0%)
#   adding: kaggle/working/4643.jpg (deflated 1%)
#   adding: kaggle/working/3722.jpg (deflated 1%)
#   adding: kaggle/working/2943.jpg (deflated 1%)
#   adding: kaggle/working/5995.jpg (deflated 1%)
#   adding: kaggle/working/2240.jpg (deflated 0%)
#   adding: kaggle/working/10016.jpg (deflated 1%)
#   adding: kaggle/working/10056.jpg (deflated 0%)
#   adding: kaggle/working/5803.jpg (deflated 1%)
#   adding: kaggle/working/6571.jpg (deflated 3%)
#   adding: kaggle/working/9303.jpg (deflated 0%)
#   adding: kaggle/working/4622.jpg (deflated 0%)
#   adding: kaggle/working/10111.jpg (deflated 0%)
#   adding: kaggle/working/2003.jpg (deflated 0%)
#   adding: kaggle/working/6995.jpg (deflated 0%)
#   adding: kaggle/working/10331.jpg (deflated 0%)
#   adding: kaggle/working/987.jpg (deflated 0%)
#   adding: kaggle/working/11470.jpg (deflated 0%)
#   adding: kaggle/working/6755.jpg (deflated 1%)
#   adding: kaggle/working/3309.jpg (deflated 0%)
#   adding: kaggle/working/4392.jpg (deflated 0%)
#   adding: kaggle/working/1201.jpg (deflated 0%)
#   adding: kaggle/working/3709.jpg (deflated 1%)
#   adding: kaggle/working/5493.jpg (deflated 0%)
#   adding: kaggle/working/1057.jpg (deflated 1%)
#   adding: kaggle/working/13341.jpg (deflated 1%)
#   adding: kaggle/working/10116.jpg (deflated 0%)
#   adding: kaggle/working/13255.jpg (deflated 1%)
#   adding: kaggle/working/13385.jpg (deflated 0%)
#   adding: kaggle/working/11477.jpg (deflated 1%)
#   adding: kaggle/working/9760.jpg (deflated 1%)
#   adding: kaggle/working/10936.jpg (deflated 1%)
#   adding: kaggle/working/9967.jpg (deflated 0%)
#   adding: kaggle/working/8858.jpg (deflated 1%)
#   adding: kaggle/working/8730.jpg (deflated 1%)
#   adding: kaggle/working/7928.jpg (deflated 1%)
#   adding: kaggle/working/11762.jpg (deflated 1%)
#   adding: kaggle/working/2769.jpg (deflated 0%)
#   adding: kaggle/working/12480.jpg (deflated 1%)
#   adding: kaggle/working/2064.jpg (deflated 0%)
#   adding: kaggle/working/4684.jpg (deflated 0%)
#   adding: kaggle/working/6481.jpg (deflated 2%)
#   adding: kaggle/working/13007.jpg (deflated 0%)
#   adding: kaggle/working/9629.jpg (deflated 2%)
#   adding: kaggle/working/3219.jpg (deflated 0%)
#   adding: kaggle/working/1208.jpg (deflated 0%)
#   adding: kaggle/working/10698.jpg (deflated 0%)
#   adding: kaggle/working/12368.jpg (deflated 1%)
#   adding: kaggle/working/7276.jpg (deflated 0%)
#   adding: kaggle/working/4672.jpg (deflated 0%)
#   adding: kaggle/working/1922.jpg (deflated 0%)
#   adding: kaggle/working/4592.jpg (deflated 0%)
#   adding: kaggle/working/9808.jpg (deflated 1%)
#   adding: kaggle/working/2261.jpg (deflated 0%)
#   adding: kaggle/working/4165.jpg (deflated 1%)
#   adding: kaggle/working/1522.jpg (deflated 2%)
#   adding: kaggle/working/13072.jpg (deflated 0%)
#   adding: kaggle/working/4515.jpg (deflated 1%)
#   adding: kaggle/working/13676.jpg (deflated 1%)
#   adding: kaggle/working/680.jpg (deflated 0%)
#   adding: kaggle/working/6408.jpg (deflated 0%)
#   adding: kaggle/working/6251.jpg (deflated 0%)
#   adding: kaggle/working/297.jpg (deflated 1%)
#   adding: kaggle/working/9015.jpg (deflated 1%)
#   adding: kaggle/working/13465.jpg (deflated 1%)
#   adding: kaggle/working/10429.jpg (deflated 0%)
#   adding: kaggle/working/1829.jpg (deflated 0%)
#   adding: kaggle/working/9004.jpg (deflated 0%)
#   adding: kaggle/working/7830.jpg (deflated 0%)
#   adding: kaggle/working/3915.jpg (deflated 0%)
#   adding: kaggle/working/4289.jpg (deflated 1%)
#   adding: kaggle/working/5875.jpg (deflated 0%)
#   adding: kaggle/working/8782.jpg (deflated 0%)
#   adding: kaggle/working/403.jpg (deflated 0%)
#   adding: kaggle/working/2194.jpg (deflated 1%)
#   adding: kaggle/working/7155.jpg (deflated 4%)
#   adding: kaggle/working/3539.jpg (deflated 1%)
#   adding: kaggle/working/10000.jpg (deflated 1%)
#   adding: kaggle/working/4869.jpg (deflated 2%)
#   adding: kaggle/working/38.jpg (deflated 1%)
#   adding: kaggle/working/5796.jpg (deflated 0%)
#   adding: kaggle/working/2670.jpg (deflated 0%)
#   adding: kaggle/working/10548.jpg (deflated 0%)
#   adding: kaggle/working/3886.jpg (deflated 2%)
#   adding: kaggle/working/13177.jpg (deflated 1%)
#   adding: kaggle/working/13134.jpg (deflated 0%)
#   adding: kaggle/working/12413.jpg (deflated 0%)
#   adding: kaggle/working/13113.jpg (deflated 0%)
#   adding: kaggle/working/354.jpg (deflated 0%)
#   adding: kaggle/working/3617.jpg (deflated 0%)
#   adding: kaggle/working/7634.jpg (deflated 0%)
#   adding: kaggle/working/10784.jpg (deflated 1%)
#   adding: kaggle/working/10851.jpg (deflated 1%)
#   adding: kaggle/working/8276.jpg (deflated 1%)
#   adding: kaggle/working/12993.jpg (deflated 0%)
#   adding: kaggle/working/8086.jpg (deflated 0%)
#   adding: kaggle/working/5345.jpg (deflated 6%)
#   adding: kaggle/working/9168.jpg (deflated 0%)
#   adding: kaggle/working/10636.jpg (deflated 0%)
#   adding: kaggle/working/6688.jpg (deflated 0%)
#   adding: kaggle/working/8280.jpg (deflated 0%)
#   adding: kaggle/working/4561.jpg (deflated 3%)
#   adding: kaggle/working/8132.jpg (deflated 0%)
#   adding: kaggle/working/3921.jpg (deflated 0%)
#   adding: kaggle/working/12693.jpg (deflated 1%)
#   adding: kaggle/working/1992.jpg (deflated 1%)
#   adding: kaggle/working/12273.jpg (deflated 0%)
#   adding: kaggle/working/13038.jpg (deflated 1%)
#   adding: kaggle/working/3359.jpg (deflated 1%)
#   adding: kaggle/working/970.jpg (deflated 0%)
#   adding: kaggle/working/151.jpg (deflated 0%)
#   adding: kaggle/working/3450.jpg (deflated 0%)
#   adding: kaggle/working/12567.jpg (deflated 0%)
#   adding: kaggle/working/11639.jpg (deflated 1%)
#   adding: kaggle/working/6600.jpg (deflated 0%)
#   adding: kaggle/working/1024.jpg (deflated 0%)
#   adding: kaggle/working/13598.jpg (deflated 1%)
#   adding: kaggle/working/8530.jpg (deflated 0%)
#   adding: kaggle/working/3870.jpg (deflated 0%)
#   adding: kaggle/working/5453.jpg (deflated 0%)
#   adding: kaggle/working/574.jpg (deflated 0%)
#   adding: kaggle/working/10121.jpg (deflated 0%)
#   adding: kaggle/working/10401.jpg (deflated 0%)
#   adding: kaggle/working/11501.jpg (deflated 1%)
#   adding: kaggle/working/748.jpg (deflated 1%)
#   adding: kaggle/working/9518.jpg (deflated 1%)
#   adding: kaggle/working/10756.jpg (deflated 2%)
#   adding: kaggle/working/1615.jpg (deflated 0%)
#   adding: kaggle/working/13466.jpg (deflated 0%)
#   adding: kaggle/working/46.jpg (deflated 0%)
#   adding: kaggle/working/4597.jpg (deflated 8%)
#   adding: kaggle/working/7462.jpg (deflated 1%)
#   adding: kaggle/working/7053.jpg (deflated 1%)
#   adding: kaggle/working/9823.jpg (deflated 1%)
#   adding: kaggle/working/11019.jpg (deflated 0%)
#   adding: kaggle/working/7562.jpg (deflated 1%)
#   adding: kaggle/working/4182.jpg (deflated 1%)
#   adding: kaggle/working/4408.jpg (deflated 0%)
#   adding: kaggle/working/9118.jpg (deflated 7%)
#   adding: kaggle/working/6579.jpg (deflated 0%)
#   adding: kaggle/working/13439.jpg (deflated 1%)
#   adding: kaggle/working/12931.jpg (deflated 2%)
#   adding: kaggle/working/3699.jpg (deflated 1%)
#   adding: kaggle/working/87.jpg (deflated 1%)
#   adding: kaggle/working/9409.jpg (deflated 0%)
#   adding: kaggle/working/1998.jpg (deflated 1%)
#   adding: kaggle/working/10035.jpg (deflated 1%)
#   adding: kaggle/working/771.jpg (deflated 1%)
#   adding: kaggle/working/9615.jpg (deflated 1%)
#   adding: kaggle/working/3376.jpg (deflated 1%)
#   adding: kaggle/working/2127.jpg (deflated 1%)
#   adding: kaggle/working/1702.jpg (deflated 1%)
#   adding: kaggle/working/8308.jpg (deflated 0%)
#   adding: kaggle/working/3859.jpg (deflated 0%)
#   adding: kaggle/working/1931.jpg (deflated 0%)
#   adding: kaggle/working/12285.jpg (deflated 0%)
#   adding: kaggle/working/5933.jpg (deflated 1%)
#   adding: kaggle/working/8991.jpg (deflated 0%)
#   adding: kaggle/working/8749.jpg (deflated 0%)
#   adding: kaggle/working/7092.jpg (deflated 1%)
#   adding: kaggle/working/4191.jpg (deflated 1%)
#   adding: kaggle/working/1710.jpg (deflated 0%)
#   adding: kaggle/working/8968.jpg (deflated 1%)
#   adding: kaggle/working/2402.jpg (deflated 0%)
#   adding: kaggle/working/2489.jpg (deflated 1%)
#   adding: kaggle/working/1320.jpg (deflated 0%)
#   adding: kaggle/working/7191.jpg (deflated 2%)
#   adding: kaggle/working/9677.jpg (deflated 0%)
#   adding: kaggle/working/3786.jpg (deflated 3%)
#   adding: kaggle/working/6187.jpg (deflated 1%)
#   adding: kaggle/working/6280.jpg (deflated 1%)
#   adding: kaggle/working/7829.jpg (deflated 1%)
#   adding: kaggle/working/5502.jpg (deflated 0%)
#   adding: kaggle/working/5033.jpg (deflated 1%)
#   adding: kaggle/working/4358.jpg (deflated 1%)
#   adding: kaggle/working/4265.jpg (deflated 1%)
#   adding: kaggle/working/3429.jpg (deflated 0%)
#   adding: kaggle/working/13407.jpg (deflated 1%)
#   adding: kaggle/working/2295.jpg (deflated 1%)
#   adding: kaggle/working/4286.jpg (deflated 2%)
#   adding: kaggle/working/4072.jpg (deflated 0%)
#   adding: kaggle/working/1856.jpg (deflated 0%)
#   adding: kaggle/working/3379.jpg (deflated 1%)
#   adding: kaggle/working/11048.jpg (deflated 1%)
#   adding: kaggle/working/4824.jpg (deflated 0%)
#   adding: kaggle/working/7020.jpg (deflated 0%)
#   adding: kaggle/working/10736.jpg (deflated 0%)
#   adding: kaggle/working/1091.jpg (deflated 1%)
#   adding: kaggle/working/1575.jpg (deflated 0%)
#   adding: kaggle/working/4087.jpg (deflated 1%)
#   adding: kaggle/working/7532.jpg (deflated 0%)
#   adding: kaggle/working/8923.jpg (deflated 0%)
#   adding: kaggle/working/3435.jpg (deflated 0%)
#   adding: kaggle/working/357.jpg (deflated 1%)
#   adding: kaggle/working/6059.jpg (deflated 1%)
#   adding: kaggle/working/3593.jpg (deflated 0%)
#   adding: kaggle/working/2586.jpg (deflated 0%)
#   adding: kaggle/working/9241.jpg (deflated 0%)
#   adding: kaggle/working/9124.jpg (deflated 7%)
#   adding: kaggle/working/6636.jpg (deflated 1%)
#   adding: kaggle/working/12978.jpg (deflated 0%)
#   adding: kaggle/working/3729.jpg (deflated 1%)
#   adding: kaggle/working/2606.jpg (deflated 0%)
#   adding: kaggle/working/9936.jpg (deflated 0%)
#   adding: kaggle/working/2719.jpg (deflated 1%)
#   adding: kaggle/working/9367.jpg (deflated 0%)
#   adding: kaggle/working/1384.jpg (deflated 1%)
#   adding: kaggle/working/8878.jpg (deflated 1%)
#   adding: kaggle/working/6000.jpg (deflated 1%)
#   adding: kaggle/working/13656.jpg (deflated 1%)
#   adding: kaggle/working/10219.jpg (deflated 1%)
#   adding: kaggle/working/12593.jpg (deflated 0%)
#   adding: kaggle/working/3947.jpg (deflated 1%)
#   adding: kaggle/working/9613.jpg (deflated 0%)
#   adding: kaggle/working/1920.jpg (deflated 0%)
#   adding: kaggle/working/13135.jpg (deflated 1%)
#   adding: kaggle/working/9552.jpg (deflated 1%)
#   adding: kaggle/working/9622.jpg (deflated 0%)
#   adding: kaggle/working/7544.jpg (deflated 1%)
#   adding: kaggle/working/12928.jpg (deflated 1%)
#   adding: kaggle/working/12704.jpg (deflated 0%)
#   adding: kaggle/working/2544.jpg (deflated 1%)
#   adding: kaggle/working/10878.jpg (deflated 0%)
#   adding: kaggle/working/6465.jpg (deflated 1%)
#   adding: kaggle/working/2212.jpg (deflated 0%)
#   adding: kaggle/working/7856.jpg (deflated 1%)
#   adding: kaggle/working/4579.jpg (deflated 1%)
#   adding: kaggle/working/1952.jpg (deflated 0%)
#   adding: kaggle/working/5838.jpg (deflated 0%)
#   adding: kaggle/working/6596.jpg (deflated 0%)
#   adding: kaggle/working/646.jpg (deflated 0%)
#   adding: kaggle/working/9219.jpg (deflated 1%)
#   adding: kaggle/working/7771.jpg (deflated 1%)
#   adding: kaggle/working/6313.jpg (deflated 2%)
#   adding: kaggle/working/11934.jpg (deflated 1%)
#   adding: kaggle/working/4757.jpg (deflated 0%)
#   adding: kaggle/working/10028.jpg (deflated 2%)
#   adding: kaggle/working/9913.jpg (deflated 1%)
#   adding: kaggle/working/11856.jpg (deflated 1%)
#   adding: kaggle/working/7913.jpg (deflated 0%)
#   adding: kaggle/working/8216.jpg (deflated 0%)
#   adding: kaggle/working/7029.jpg (deflated 0%)
#   adding: kaggle/working/8633.jpg (deflated 3%)
#   adding: kaggle/working/8397.jpg (deflated 0%)
#   adding: kaggle/working/4640.jpg (deflated 0%)
#   adding: kaggle/working/2354.jpg (deflated 2%)
#   adding: kaggle/working/6116.jpg (deflated 0%)
#   adding: kaggle/working/4828.jpg (deflated 1%)
#   adding: kaggle/working/712.jpg (deflated 0%)
#   adding: kaggle/working/5666.jpg (deflated 2%)
#   adding: kaggle/working/9121.jpg (deflated 1%)
#   adding: kaggle/working/2612.jpg (deflated 0%)
#   adding: kaggle/working/5195.jpg (deflated 1%)
#   adding: kaggle/working/2673.jpg (deflated 0%)
#   adding: kaggle/working/6383.jpg (deflated 1%)
#   adding: kaggle/working/8503.jpg (deflated 0%)
#   adding: kaggle/working/11086.jpg (deflated 1%)
#   adding: kaggle/working/640.jpg (deflated 0%)
#   adding: kaggle/working/1328.jpg (deflated 0%)
#   adding: kaggle/working/4708.jpg (deflated 1%)
#   adding: kaggle/working/8863.jpg (deflated 0%)
#   adding: kaggle/working/2493.jpg (deflated 0%)
#   adding: kaggle/working/1083.jpg (deflated 1%)
#   adding: kaggle/working/2326.jpg (deflated 1%)
#   adding: kaggle/working/8428.jpg (deflated 1%)
#   adding: kaggle/working/7924.jpg (deflated 0%)
#   adding: kaggle/working/10663.jpg (deflated 0%)
#   adding: kaggle/working/10033.jpg (deflated 0%)
#   adding: kaggle/working/7465.jpg (deflated 1%)
#   adding: kaggle/working/7212.jpg (deflated 0%)
#   adding: kaggle/working/6433.jpg (deflated 1%)
#   adding: kaggle/working/10655.jpg (deflated 0%)
#   adding: kaggle/working/7930.jpg (deflated 0%)
#   adding: kaggle/working/7170.jpg (deflated 0%)
#   adding: kaggle/working/6938.jpg (deflated 2%)
#   adding: kaggle/working/3071.jpg (deflated 1%)
#   adding: kaggle/working/12238.jpg (deflated 0%)
#   adding: kaggle/working/249.jpg (deflated 0%)
#   adding: kaggle/working/1604.jpg (deflated 0%)
#   adding: kaggle/working/10088.jpg (deflated 0%)
#   adding: kaggle/working/12514.jpg (deflated 1%)
#   adding: kaggle/working/9218.jpg (deflated 2%)
#   adding: kaggle/working/11890.jpg (deflated 0%)
#   adding: kaggle/working/13538.jpg (deflated 0%)
#   adding: kaggle/working/8609.jpg (deflated 1%)
#   adding: kaggle/working/8490.jpg (deflated 1%)
#   adding: kaggle/working/13355.jpg (deflated 1%)
#   adding: kaggle/working/3820.jpg (deflated 1%)
#   adding: kaggle/working/7745.jpg (deflated 1%)
#   adding: kaggle/working/4107.jpg (deflated 0%)
#   adding: kaggle/working/6778.jpg (deflated 0%)
#   adding: kaggle/working/9646.jpg (deflated 0%)
#   adding: kaggle/working/9086.jpg (deflated 0%)
#   adding: kaggle/working/12322.jpg (deflated 1%)
#   adding: kaggle/working/8036.jpg (deflated 1%)
#   adding: kaggle/working/2571.jpg (deflated 2%)
#   adding: kaggle/working/5965.jpg (deflated 2%)
#   adding: kaggle/working/6972.jpg (deflated 1%)
#   adding: kaggle/working/5385.jpg (deflated 1%)
#   adding: kaggle/working/2597.jpg (deflated 1%)
#   adding: kaggle/working/8507.jpg (deflated 1%)
#   adding: kaggle/working/9443.jpg (deflated 0%)
#   adding: kaggle/working/9598.jpg (deflated 0%)
#   adding: kaggle/working/6256.jpg (deflated 0%)
#   adding: kaggle/working/1572.jpg (deflated 1%)
#   adding: kaggle/working/8205.jpg (deflated 1%)
#   adding: kaggle/working/13703.jpg (deflated 1%)
#   adding: kaggle/working/12531.jpg (deflated 1%)
#   adding: kaggle/working/12837.jpg (deflated 1%)
#   adding: kaggle/working/3603.jpg (deflated 1%)
#   adding: kaggle/working/7579.jpg (deflated 0%)
#   adding: kaggle/working/11135.jpg (deflated 1%)
#   adding: kaggle/working/7112.jpg (deflated 0%)
#   adding: kaggle/working/12499.jpg (deflated 5%)
#   adding: kaggle/working/1117.jpg (deflated 1%)
#   adding: kaggle/working/2916.jpg (deflated 0%)
#   adding: kaggle/working/7431.jpg (deflated 1%)
#   adding: kaggle/working/4888.jpg (deflated 1%)
#   adding: kaggle/working/523.jpg (deflated 1%)
#   adding: kaggle/working/837.jpg (deflated 0%)
#   adding: kaggle/working/4800.jpg (deflated 2%)
#   adding: kaggle/working/6553.jpg (deflated 0%)
#   adding: kaggle/working/3653.jpg (deflated 1%)
#   adding: kaggle/working/6347.jpg (deflated 1%)
#   adding: kaggle/working/256.jpg (deflated 1%)
#   adding: kaggle/working/1919.jpg (deflated 0%)
#   adding: kaggle/working/3890.jpg (deflated 0%)
#   adding: kaggle/working/5847.jpg (deflated 0%)
#   adding: kaggle/working/3389.jpg (deflated 0%)
#   adding: kaggle/working/372.jpg (deflated 0%)
#   adding: kaggle/working/10823.jpg (deflated 0%)
#   adding: kaggle/working/11397.jpg (deflated 0%)
#   adding: kaggle/working/2164.jpg (deflated 1%)
#   adding: kaggle/working/8532.jpg (deflated 1%)
#   adding: kaggle/working/9288.jpg (deflated 0%)
#   adding: kaggle/working/7357.jpg (deflated 0%)
#   adding: kaggle/working/3796.jpg (deflated 1%)
#   adding: kaggle/working/9993.jpg (deflated 1%)
#   adding: kaggle/working/438.jpg (deflated 1%)
#   adding: kaggle/working/8693.jpg (deflated 0%)
#   adding: kaggle/working/2818.jpg (deflated 0%)
#   adding: kaggle/working/12213.jpg (deflated 1%)
#   adding: kaggle/working/1616.jpg (deflated 0%)
#   adding: kaggle/working/117.jpg (deflated 7%)
#   adding: kaggle/working/1799.jpg (deflated 0%)
#   adding: kaggle/working/8661.jpg (deflated 0%)
#   adding: kaggle/working/4106.jpg (deflated 1%)
#   adding: kaggle/working/5325.jpg (deflated 4%)
#   adding: kaggle/working/5313.jpg (deflated 1%)
#   adding: kaggle/working/11948.jpg (deflated 1%)
#   adding: kaggle/working/4514.jpg (deflated 0%)
#   adding: kaggle/working/2773.jpg (deflated 0%)
#   adding: kaggle/working/9107.jpg (deflated 0%)
#   adding: kaggle/working/9286.jpg (deflated 1%)
#   adding: kaggle/working/8594.jpg (deflated 1%)
#   adding: kaggle/working/13326.jpg (deflated 3%)
#   adding: kaggle/working/971.jpg (deflated 1%)
#   adding: kaggle/working/9152.jpg (deflated 0%)
#   adding: kaggle/working/12298.jpg (deflated 2%)
#   adding: kaggle/working/11203.jpg (deflated 0%)
#   adding: kaggle/working/12153.jpg (deflated 0%)
#   adding: kaggle/working/5603.jpg (deflated 0%)
#   adding: kaggle/working/4653.jpg (deflated 1%)
#   adding: kaggle/working/2128.jpg (deflated 0%)
#   adding: kaggle/working/9378.jpg (deflated 0%)
#   adding: kaggle/working/3346.jpg (deflated 0%)
#   adding: kaggle/working/4146.jpg (deflated 0%)
#   adding: kaggle/working/4728.jpg (deflated 0%)
#   adding: kaggle/working/13464.jpg (deflated 0%)
#   adding: kaggle/working/11103.jpg (deflated 1%)
#   adding: kaggle/working/10313.jpg (deflated 1%)
#   adding: kaggle/working/621.jpg (deflated 0%)
#   adding: kaggle/working/4172.jpg (deflated 0%)
#   adding: kaggle/working/7707.jpg (deflated 3%)
#   adding: kaggle/working/7204.jpg (deflated 2%)
#   adding: kaggle/working/5112.jpg (deflated 2%)
#   adding: kaggle/working/7437.jpg (deflated 0%)
#   adding: kaggle/working/5242.jpg (deflated 0%)
#   adding: kaggle/working/6936.jpg (deflated 0%)
#   adding: kaggle/working/4555.jpg (deflated 0%)
#   adding: kaggle/working/5923.jpg (deflated 0%)
#   adding: kaggle/working/6215.jpg (deflated 1%)
#   adding: kaggle/working/7518.jpg (deflated 0%)
#   adding: kaggle/working/9115.jpg (deflated 1%)
#   adding: kaggle/working/10882.jpg (deflated 0%)
#   adding: kaggle/working/7534.jpg (deflated 0%)
#   adding: kaggle/working/10954.jpg (deflated 0%)
#   adding: kaggle/working/9235.jpg (deflated 0%)
#   adding: kaggle/working/3277.jpg (deflated 0%)
#   adding: kaggle/working/147.jpg (deflated 1%)
#   adding: kaggle/working/824.jpg (deflated 1%)
#   adding: kaggle/working/1409.jpg (deflated 0%)
#   adding: kaggle/working/4777.jpg (deflated 0%)
#   adding: kaggle/working/6928.jpg (deflated 1%)
#   adding: kaggle/working/8684.jpg (deflated 0%)
#   adding: kaggle/working/416.jpg (deflated 0%)
#   adding: kaggle/working/5983.jpg (deflated 0%)
#   adding: kaggle/working/10237.jpg (deflated 1%)
#   adding: kaggle/working/303.jpg (deflated 1%)
#   adding: kaggle/working/4370.jpg (deflated 0%)
#   adding: kaggle/working/9528.jpg (deflated 1%)
#   adding: kaggle/working/11215.jpg (deflated 0%)
#   adding: kaggle/working/2888.jpg (deflated 0%)
#   adding: kaggle/working/5710.jpg (deflated 0%)
#   adding: kaggle/working/3562.jpg (deflated 1%)
#   adding: kaggle/working/10708.jpg (deflated 0%)
#   adding: kaggle/working/4646.jpg (deflated 1%)
#   adding: kaggle/working/3364.jpg (deflated 1%)
#   adding: kaggle/working/13262.jpg (deflated 1%)
#   adding: kaggle/working/6897.jpg (deflated 1%)
#   adding: kaggle/working/8915.jpg (deflated 0%)
#   adding: kaggle/working/6242.jpg (deflated 1%)
#   adding: kaggle/working/10844.jpg (deflated 2%)
#   adding: kaggle/working/1385.jpg (deflated 0%)
#   adding: kaggle/working/10437.jpg (deflated 1%)
#   adding: kaggle/working/3519.jpg (deflated 0%)
#   adding: kaggle/working/2183.jpg (deflated 0%)
#   adding: kaggle/working/3327.jpg (deflated 1%)
#   adding: kaggle/working/9776.jpg (deflated 1%)
#   adding: kaggle/working/3567.jpg (deflated 1%)
#   adding: kaggle/working/3132.jpg (deflated 2%)
#   adding: kaggle/working/5619.jpg (deflated 0%)
#   adding: kaggle/working/1184.jpg (deflated 1%)
#   adding: kaggle/working/9635.jpg (deflated 0%)
#   adding: kaggle/working/10701.jpg (deflated 2%)
#   adding: kaggle/working/2100.jpg (deflated 0%)
#   adding: kaggle/working/3394.jpg (deflated 1%)
#   adding: kaggle/working/2483.jpg (deflated 0%)
#   adding: kaggle/working/13338.jpg (deflated 0%)
#   adding: kaggle/working/10183.jpg (deflated 0%)
#   adding: kaggle/working/11751.jpg (deflated 1%)
#   adding: kaggle/working/5954.jpg (deflated 1%)
#   adding: kaggle/working/5126.jpg (deflated 0%)
#   adding: kaggle/working/10600.jpg (deflated 1%)
#   adding: kaggle/working/12419.jpg (deflated 4%)
#   adding: kaggle/working/495.jpg (deflated 0%)
#   adding: kaggle/working/4180.jpg (deflated 1%)
#   adding: kaggle/working/4742.jpg (deflated 1%)
#   adding: kaggle/working/1824.jpg (deflated 1%)
#   adding: kaggle/working/1739.jpg (deflated 0%)
#   adding: kaggle/working/385.jpg (deflated 0%)
#   adding: kaggle/working/2414.jpg (deflated 0%)
#   adding: kaggle/working/7672.jpg (deflated 0%)
#   adding: kaggle/working/7472.jpg (deflated 1%)
#   adding: kaggle/working/13721.jpg (deflated 0%)
#   adding: kaggle/working/3267.jpg (deflated 0%)
#   adding: kaggle/working/8099.jpg (deflated 1%)
#   adding: kaggle/working/3613.jpg (deflated 7%)
#   adding: kaggle/working/6821.jpg (deflated 0%)
#   adding: kaggle/working/9789.jpg (deflated 0%)
#   adding: kaggle/working/9496.jpg (deflated 1%)
#   adding: kaggle/working/5416.jpg (deflated 0%)
#   adding: kaggle/working/74.jpg (deflated 0%)
#   adding: kaggle/working/8321.jpg (deflated 0%)
#   adding: kaggle/working/8013.jpg (deflated 0%)
#   adding: kaggle/working/1213.jpg (deflated 0%)
#   adding: kaggle/working/7367.jpg (deflated 1%)
#   adding: kaggle/working/3802.jpg (deflated 1%)
#   adding: kaggle/working/11285.jpg (deflated 0%)
#   adding: kaggle/working/7748.jpg (deflated 0%)
#   adding: kaggle/working/6612.jpg (deflated 6%)
#   adding: kaggle/working/2817.jpg (deflated 0%)
#   adding: kaggle/working/4652.jpg (deflated 0%)
#   adding: kaggle/working/9256.jpg (deflated 0%)
#   adding: kaggle/working/3550.jpg (deflated 1%)
#   adding: kaggle/working/3700.jpg (deflated 1%)
#   adding: kaggle/working/10715.jpg (deflated 0%)
#   adding: kaggle/working/2961.jpg (deflated 0%)
#   adding: kaggle/working/10750.jpg (deflated 0%)
#   adding: kaggle/working/7377.jpg (deflated 1%)
#   adding: kaggle/working/4785.jpg (deflated 0%)
#   adding: kaggle/working/8333.jpg (deflated 1%)
#   adding: kaggle/working/10522.jpg (deflated 0%)
#   adding: kaggle/working/11032.jpg (deflated 0%)
#   adding: kaggle/working/7154.jpg (deflated 1%)
#   adding: kaggle/working/10521.jpg (deflated 1%)
#   adding: kaggle/working/4583.jpg (deflated 8%)
#   adding: kaggle/working/11712.jpg (deflated 1%)
#   adding: kaggle/working/11754.jpg (deflated 0%)
#   adding: kaggle/working/11421.jpg (deflated 1%)
#   adding: kaggle/working/5853.jpg (deflated 1%)
#   adding: kaggle/working/3489.jpg (deflated 2%)
#   adding: kaggle/working/12492.jpg (deflated 0%)
#   adding: kaggle/working/13337.jpg (deflated 2%)
#   adding: kaggle/working/12868.jpg (deflated 2%)
#   adding: kaggle/working/9116.jpg (deflated 2%)
#   adding: kaggle/working/12046.jpg (deflated 0%)
#   adding: kaggle/working/9495.jpg (deflated 0%)
#   adding: kaggle/working/2346.jpg (deflated 1%)
#   adding: kaggle/working/5564.jpg (deflated 0%)
#   adding: kaggle/working/5966.jpg (deflated 0%)
#   adding: kaggle/working/7513.jpg (deflated 1%)
#   adding: kaggle/working/7848.jpg (deflated 1%)
#   adding: kaggle/working/2761.jpg (deflated 1%)
#   adding: kaggle/working/6799.jpg (deflated 0%)
#   adding: kaggle/working/4988.jpg (deflated 0%)
#   adding: kaggle/working/1535.jpg (deflated 1%)
#   adding: kaggle/working/4922.jpg (deflated 0%)
#   adding: kaggle/working/3973.jpg (deflated 0%)
#   adding: kaggle/working/3715.jpg (deflated 1%)
#   adding: kaggle/working/8639.jpg (deflated 2%)
#   adding: kaggle/working/4320.jpg (deflated 0%)
#   adding: kaggle/working/5020.jpg (deflated 0%)
#   adding: kaggle/working/1633.jpg (deflated 0%)
#   adding: kaggle/working/10592.jpg (deflated 1%)
#   adding: kaggle/working/12527.jpg (deflated 1%)
#   adding: kaggle/working/4718.jpg (deflated 0%)
#   adding: kaggle/working/4335.jpg (deflated 1%)
#   adding: kaggle/working/7226.jpg (deflated 1%)
#   adding: kaggle/working/10658.jpg (deflated 0%)
#   adding: kaggle/working/10070.jpg (deflated 1%)
#   adding: kaggle/working/3263.jpg (deflated 0%)
#   adding: kaggle/working/11481.jpg (deflated 0%)
#   adding: kaggle/working/11596.jpg (deflated 1%)
#   adding: kaggle/working/5052.jpg (deflated 1%)
#   adding: kaggle/working/2057.jpg (deflated 0%)
#   adding: kaggle/working/11956.jpg (deflated 1%)
#   adding: kaggle/working/4479.jpg (deflated 0%)
#   adding: kaggle/working/5236.jpg (deflated 0%)
#   adding: kaggle/working/775.jpg (deflated 1%)
#   adding: kaggle/working/6107.jpg (deflated 0%)
#   adding: kaggle/working/9047.jpg (deflated 0%)
#   adding: kaggle/working/7574.jpg (deflated 1%)
#   adding: kaggle/working/3635.jpg (deflated 1%)
#   adding: kaggle/working/6606.jpg (deflated 0%)
#   adding: kaggle/working/8985.jpg (deflated 0%)
#   adding: kaggle/working/6395.jpg (deflated 0%)
#   adding: kaggle/working/13138.jpg (deflated 1%)
#   adding: kaggle/working/12916.jpg (deflated 0%)
#   adding: kaggle/working/4404.jpg (deflated 1%)
#   adding: kaggle/working/4987.jpg (deflated 2%)
#   adding: kaggle/working/573.jpg (deflated 1%)
#   adding: kaggle/working/3975.jpg (deflated 1%)
#   adding: kaggle/working/6179.jpg (deflated 1%)
#   adding: kaggle/working/9333.jpg (deflated 0%)
#   adding: kaggle/working/1623.jpg (deflated 2%)
#   adding: kaggle/working/815.jpg (deflated 1%)
#   adding: kaggle/working/2302.jpg (deflated 0%)
#   adding: kaggle/working/681.jpg (deflated 1%)
#   adding: kaggle/working/412.jpg (deflated 1%)
#   adding: kaggle/working/5094.jpg (deflated 1%)
#   adding: kaggle/working/7432.jpg (deflated 0%)
#   adding: kaggle/working/12287.jpg (deflated 2%)
#   adding: kaggle/working/1273.jpg (deflated 1%)
#   adding: kaggle/working/4629.jpg (deflated 1%)
#   adding: kaggle/working/10950.jpg (deflated 0%)
#   adding: kaggle/working/1029.jpg (deflated 0%)
#   adding: kaggle/working/367.jpg (deflated 1%)
#   adding: kaggle/working/1150.jpg (deflated 1%)
#   adding: kaggle/working/5748.jpg (deflated 1%)
#   adding: kaggle/working/7760.jpg (deflated 0%)
#   adding: kaggle/working/3549.jpg (deflated 0%)
#   adding: kaggle/working/8665.jpg (deflated 1%)
#   adding: kaggle/working/5836.jpg (deflated 0%)
#   adding: kaggle/working/11265.jpg (deflated 0%)
#   adding: kaggle/working/12569.jpg (deflated 0%)
#   adding: kaggle/working/873.jpg (deflated 0%)
#   adding: kaggle/working/154.jpg (deflated 0%)
#   adding: kaggle/working/336.jpg (deflated 0%)
#   adding: kaggle/working/12971.jpg (deflated 0%)
#   adding: kaggle/working/6484.jpg (deflated 0%)
#   adding: kaggle/working/7040.jpg (deflated 0%)
#   adding: kaggle/working/3589.jpg (deflated 1%)
#   adding: kaggle/working/11848.jpg (deflated 0%)
#   adding: kaggle/working/3989.jpg (deflated 1%)
#   adding: kaggle/working/306.jpg (deflated 2%)
#   adding: kaggle/working/4433.jpg (deflated 1%)
#   adding: kaggle/working/1621.jpg (deflated 1%)
#   adding: kaggle/working/2257.jpg (deflated 4%)
#   adding: kaggle/working/5970.jpg (deflated 1%)
#   adding: kaggle/working/13681.jpg (deflated 4%)
#   adding: kaggle/working/10561.jpg (deflated 0%)
#   adding: kaggle/working/4648.jpg (deflated 0%)
#   adding: kaggle/working/6300.jpg (deflated 1%)
#   adding: kaggle/working/2019.jpg (deflated 2%)
#   adding: kaggle/working/3281.jpg (deflated 0%)
#   adding: kaggle/working/5412.jpg (deflated 1%)
#   adding: kaggle/working/11559.jpg (deflated 0%)
#   adding: kaggle/working/11690.jpg (deflated 1%)
#   adding: kaggle/working/10888.jpg (deflated 1%)
#   adding: kaggle/working/762.jpg (deflated 1%)
#   adding: kaggle/working/8110.jpg (deflated 1%)
#   adding: kaggle/working/11818.jpg (deflated 0%)
#   adding: kaggle/working/12816.jpg (deflated 0%)
#   adding: kaggle/working/8585.jpg (deflated 0%)
#   adding: kaggle/working/9141.jpg (deflated 0%)
#   adding: kaggle/working/453.jpg (deflated 1%)
#   adding: kaggle/working/13234.jpg (deflated 0%)
#   adding: kaggle/working/8525.jpg (deflated 1%)
#   adding: kaggle/working/7917.jpg (deflated 1%)
#   adding: kaggle/working/2131.jpg (deflated 1%)
#   adding: kaggle/working/12570.jpg (deflated 0%)
#   adding: kaggle/working/13159.jpg (deflated 0%)
#   adding: kaggle/working/9825.jpg (deflated 1%)
#   adding: kaggle/working/5856.jpg (deflated 1%)
#   adding: kaggle/working/276.jpg (deflated 1%)
#   adding: kaggle/working/11026.jpg (deflated 1%)
#   adding: kaggle/working/11078.jpg (deflated 0%)
#   adding: kaggle/working/13054.jpg (deflated 1%)
#   adding: kaggle/working/5788.jpg (deflated 0%)
#   adding: kaggle/working/8500.jpg (deflated 0%)
#   adding: kaggle/working/13553.jpg (deflated 1%)
#   adding: kaggle/working/4379.jpg (deflated 0%)
#   adding: kaggle/working/10459.jpg (deflated 0%)
#   adding: kaggle/working/12475.jpg (deflated 1%)
#   adding: kaggle/working/12012.jpg (deflated 1%)
#   adding: kaggle/working/8739.jpg (deflated 1%)
#   adding: kaggle/working/6134.jpg (deflated 1%)
#   adding: kaggle/working/1493.jpg (deflated 1%)
#   adding: kaggle/working/4905.jpg (deflated 1%)
#   adding: kaggle/working/5153.jpg (deflated 1%)
#   adding: kaggle/working/5540.jpg (deflated 0%)
#   adding: kaggle/working/8226.jpg (deflated 1%)
#   adding: kaggle/working/7306.jpg (deflated 1%)
#   adding: kaggle/working/3166.jpg (deflated 3%)
#   adding: kaggle/working/10416.jpg (deflated 5%)
#   adding: kaggle/working/9912.jpg (deflated 0%)
#   adding: kaggle/working/3897.jpg (deflated 0%)
#   adding: kaggle/working/3206.jpg (deflated 0%)
#   adding: kaggle/working/8713.jpg (deflated 1%)
#   adding: kaggle/working/8689.jpg (deflated 1%)
#   adding: kaggle/working/2795.jpg (deflated 1%)
#   adding: kaggle/working/10570.jpg (deflated 1%)
#   adding: kaggle/working/6117.jpg (deflated 0%)
#   adding: kaggle/working/12830.jpg (deflated 0%)
#   adding: kaggle/working/13123.jpg (deflated 0%)
#   adding: kaggle/working/100.jpg (deflated 0%)
#   adding: kaggle/working/2275.jpg (deflated 0%)
#   adding: kaggle/working/12571.jpg (deflated 0%)
#   adding: kaggle/working/2325.jpg (deflated 0%)
#   adding: kaggle/working/4873.jpg (deflated 1%)
#   adding: kaggle/working/7570.jpg (deflated 3%)
#   adding: kaggle/working/8108.jpg (deflated 0%)
#   adding: kaggle/working/2318.jpg (deflated 0%)
#   adding: kaggle/working/819.jpg (deflated 1%)
#   adding: kaggle/working/9030.jpg (deflated 1%)
#   adding: kaggle/working/8745.jpg (deflated 1%)
#   adding: kaggle/working/12065.jpg (deflated 1%)
#   adding: kaggle/working/2991.jpg (deflated 1%)
#   adding: kaggle/working/5380.jpg (deflated 1%)
#   adding: kaggle/working/7250.jpg (deflated 1%)
#   adding: kaggle/working/9555.jpg (deflated 2%)
#   adding: kaggle/working/12086.jpg (deflated 0%)
#   adding: kaggle/working/11602.jpg (deflated 0%)
#   adding: kaggle/working/13491.jpg (deflated 0%)
#   adding: kaggle/working/2777.jpg (deflated 1%)
#   adding: kaggle/working/11499.jpg (deflated 0%)
#   adding: kaggle/working/340.jpg (deflated 1%)
#   adding: kaggle/working/12023.jpg (deflated 1%)
#   adding: kaggle/working/695.jpg (deflated 1%)
#   adding: kaggle/working/4453.jpg (deflated 0%)
#   adding: kaggle/working/10171.jpg (deflated 0%)
#   adding: kaggle/working/4171.jpg (deflated 0%)
#   adding: kaggle/working/780.jpg (deflated 1%)
#   adding: kaggle/working/9517.jpg (deflated 0%)
#   adding: kaggle/working/9824.jpg (deflated 1%)
#   adding: kaggle/working/1586.jpg (deflated 0%)
#   adding: kaggle/working/10405.jpg (deflated 1%)
#   adding: kaggle/working/4562.jpg (deflated 1%)
#   adding: kaggle/working/4749.jpg (deflated 0%)
#   adding: kaggle/working/10141.jpg (deflated 0%)
#   adding: kaggle/working/10122.jpg (deflated 0%)
#   adding: kaggle/working/7828.jpg (deflated 1%)
#   adding: kaggle/working/8480.jpg (deflated 2%)
#   adding: kaggle/working/3669.jpg (deflated 0%)
#   adding: kaggle/working/4336.jpg (deflated 0%)
#   adding: kaggle/working/7177.jpg (deflated 1%)
#   adding: kaggle/working/3266.jpg (deflated 1%)
#   adding: kaggle/working/6099.jpg (deflated 0%)
#   adding: kaggle/working/9364.jpg (deflated 1%)
#   adding: kaggle/working/6506.jpg (deflated 1%)
#   adding: kaggle/working/2850.jpg (deflated 0%)
#   adding: kaggle/working/33.jpg (deflated 0%)
#   adding: kaggle/working/2056.jpg (deflated 0%)
#   adding: kaggle/working/13353.jpg (deflated 1%)
#   adding: kaggle/working/5137.jpg (deflated 1%)
#   adding: kaggle/working/9108.jpg (deflated 1%)
#   adding: kaggle/working/10697.jpg (deflated 1%)
#   adding: kaggle/working/13577.jpg (deflated 0%)
#   adding: kaggle/working/9436.jpg (deflated 0%)
#   adding: kaggle/working/6990.jpg (deflated 0%)
#   adding: kaggle/working/8105.jpg (deflated 2%)
#   adding: kaggle/working/6102.jpg (deflated 2%)
#   adding: kaggle/working/835.jpg (deflated 1%)
#   adding: kaggle/working/10910.jpg (deflated 0%)
#   adding: kaggle/working/1791.jpg (deflated 0%)
#   adding: kaggle/working/4675.jpg (deflated 1%)
#   adding: kaggle/working/1447.jpg (deflated 4%)
#   adding: kaggle/working/1743.jpg (deflated 0%)
#   adding: kaggle/working/1929.jpg (deflated 0%)
#   adding: kaggle/working/3529.jpg (deflated 1%)
#   adding: kaggle/working/6225.jpg (deflated 0%)
#   adding: kaggle/working/5090.jpg (deflated 1%)
#   adding: kaggle/working/5251.jpg (deflated 0%)
#   adding: kaggle/working/8298.jpg (deflated 0%)
#   adding: kaggle/working/12723.jpg (deflated 1%)
#   adding: kaggle/working/10230.jpg (deflated 0%)
#   adding: kaggle/working/9313.jpg (deflated 0%)
#   adding: kaggle/working/13302.jpg (deflated 0%)
#   adding: kaggle/working/12574.jpg (deflated 1%)
#   adding: kaggle/working/3222.jpg (deflated 4%)
#   adding: kaggle/working/11930.jpg (deflated 1%)
#   adding: kaggle/working/13103.jpg (deflated 1%)
#   adding: kaggle/working/12858.jpg (deflated 1%)
#   adding: kaggle/working/3910.jpg (deflated 0%)
#   adding: kaggle/working/1272.jpg (deflated 1%)
#   adding: kaggle/working/282.jpg (deflated 0%)
#   adding: kaggle/working/8929.jpg (deflated 1%)
#   adding: kaggle/working/825.jpg (deflated 1%)
#   adding: kaggle/working/3099.jpg (deflated 0%)
#   adding: kaggle/working/8543.jpg (deflated 1%)
#   adding: kaggle/working/9129.jpg (deflated 1%)
#   adding: kaggle/working/8592.jpg (deflated 1%)
#   adding: kaggle/working/9928.jpg (deflated 1%)
#   adding: kaggle/working/2441.jpg (deflated 1%)
#   adding: kaggle/working/10336.jpg (deflated 1%)
#   adding: kaggle/working/1270.jpg (deflated 0%)
#   adding: kaggle/working/978.jpg (deflated 0%)
#   adding: kaggle/working/8992.jpg (deflated 0%)
#   adding: kaggle/working/9878.jpg (deflated 0%)
#   adding: kaggle/working/3045.jpg (deflated 0%)
#   adding: kaggle/working/5197.jpg (deflated 0%)
#   adding: kaggle/working/6906.jpg (deflated 0%)
#   adding: kaggle/working/671.jpg (deflated 1%)
#   adding: kaggle/working/2927.jpg (deflated 0%)
#   adding: kaggle/working/1709.jpg (deflated 1%)
#   adding: kaggle/working/1894.jpg (deflated 0%)
#   adding: kaggle/working/11113.jpg (deflated 0%)
#   adding: kaggle/working/4382.jpg (deflated 0%)
#   adding: kaggle/working/3580.jpg (deflated 0%)
#   adding: kaggle/working/1900.jpg (deflated 0%)
#   adding: kaggle/working/5286.jpg (deflated 4%)
#   adding: kaggle/working/10246.jpg (deflated 2%)
#   adding: kaggle/working/665.jpg (deflated 2%)
#   adding: kaggle/working/5549.jpg (deflated 1%)
#   adding: kaggle/working/4032.jpg (deflated 2%)
#   adding: kaggle/working/11606.jpg (deflated 0%)
#   adding: kaggle/working/4241.jpg (deflated 1%)
#   adding: kaggle/working/111.jpg (deflated 1%)
#   adding: kaggle/working/4542.jpg (deflated 1%)
#   adding: kaggle/working/5561.jpg (deflated 1%)
#   adding: kaggle/working/1329.jpg (deflated 0%)
#   adding: kaggle/working/7501.jpg (deflated 1%)
#   adding: kaggle/working/7309.jpg (deflated 1%)
#   adding: kaggle/working/11408.jpg (deflated 1%)
#   adding: kaggle/working/4446.jpg (deflated 1%)
#   adding: kaggle/working/5163.jpg (deflated 7%)
#   adding: kaggle/working/9975.jpg (deflated 1%)
#   adding: kaggle/working/4736.jpg (deflated 2%)
#   adding: kaggle/working/6386.jpg (deflated 1%)
#   adding: kaggle/working/12348.jpg (deflated 1%)
#   adding: kaggle/working/3869.jpg (deflated 2%)
#   adding: kaggle/working/782.jpg (deflated 3%)
#   adding: kaggle/working/8139.jpg (deflated 1%)
#   adding: kaggle/working/3275.jpg (deflated 1%)
#   adding: kaggle/working/3945.jpg (deflated 0%)
#   adding: kaggle/working/6399.jpg (deflated 1%)
#   adding: kaggle/working/8174.jpg (deflated 1%)
#   adding: kaggle/working/1706.jpg (deflated 1%)
#   adding: kaggle/working/477.jpg (deflated 1%)
#   adding: kaggle/working/13729.jpg (deflated 5%)
#   adding: kaggle/working/1649.jpg (deflated 1%)
#   adding: kaggle/working/1226.jpg (deflated 1%)
#   adding: kaggle/working/13456.jpg (deflated 2%)
#   adding: kaggle/working/4352.jpg (deflated 1%)
#   adding: kaggle/working/10782.jpg (deflated 0%)
#   adding: kaggle/working/3245.jpg (deflated 0%)
#   adding: kaggle/working/807.jpg (deflated 2%)
#   adding: kaggle/working/11193.jpg (deflated 0%)
#   adding: kaggle/working/7736.jpg (deflated 0%)
#   adding: kaggle/working/7871.jpg (deflated 1%)
#   adding: kaggle/working/12020.jpg (deflated 0%)
#   adding: kaggle/working/1425.jpg (deflated 1%)
#   adding: kaggle/working/7419.jpg (deflated 1%)
#   adding: kaggle/working/12077.jpg (deflated 0%)
#   adding: kaggle/working/1462.jpg (deflated 0%)
#   adding: kaggle/working/2938.jpg (deflated 1%)
#   adding: kaggle/working/2663.jpg (deflated 2%)
#   adding: kaggle/working/9136.jpg (deflated 0%)
#   adding: kaggle/working/4426.jpg (deflated 0%)
#   adding: kaggle/working/11940.jpg (deflated 1%)
#   adding: kaggle/working/696.jpg (deflated 1%)
#   adding: kaggle/working/12374.jpg (deflated 1%)
#   adding: kaggle/working/10861.jpg (deflated 1%)
#   adding: kaggle/working/3260.jpg (deflated 0%)
#   adding: kaggle/working/1734.jpg (deflated 0%)
#   adding: kaggle/working/12538.jpg (deflated 1%)
#   adding: kaggle/working/6418.jpg (deflated 6%)
#   adding: kaggle/working/6189.jpg (deflated 1%)
#   adding: kaggle/working/9820.jpg (deflated 0%)
#   adding: kaggle/working/6384.jpg (deflated 7%)
#   adding: kaggle/working/11036.jpg (deflated 4%)
#   adding: kaggle/working/5675.jpg (deflated 0%)
#   adding: kaggle/working/2084.jpg (deflated 0%)
#   adding: kaggle/working/7815.jpg (deflated 0%)
#   adding: kaggle/working/537.jpg (deflated 1%)
#   adding: kaggle/working/1228.jpg (deflated 2%)
#   adding: kaggle/working/5211.jpg (deflated 0%)
#   adding: kaggle/working/11252.jpg (deflated 0%)
#   adding: kaggle/working/7202.jpg (deflated 0%)
#   adding: kaggle/working/1553.jpg (deflated 1%)
#   adding: kaggle/working/10622.jpg (deflated 1%)
#   adding: kaggle/working/8914.jpg (deflated 0%)
#   adding: kaggle/working/12180.jpg (deflated 2%)
#   adding: kaggle/working/11398.jpg (deflated 0%)
#   adding: kaggle/working/8647.jpg (deflated 0%)
#   adding: kaggle/working/2252.jpg (deflated 0%)
#   adding: kaggle/working/7728.jpg (deflated 0%)
#   adding: kaggle/working/11588.jpg (deflated 2%)
#   adding: kaggle/working/9466.jpg (deflated 0%)
#   adding: kaggle/working/342.jpg (deflated 1%)
#   adding: kaggle/working/10765.jpg (deflated 1%)
#   adding: kaggle/working/7912.jpg (deflated 1%)
#   adding: kaggle/working/7915.jpg (deflated 0%)
#   adding: kaggle/working/8842.jpg (deflated 1%)
#   adding: kaggle/working/4118.jpg (deflated 0%)
#   adding: kaggle/working/1032.jpg (deflated 0%)
#   adding: kaggle/working/1094.jpg (deflated 1%)
#   adding: kaggle/working/11098.jpg (deflated 1%)
#   adding: kaggle/working/2935.jpg (deflated 0%)
#   adding: kaggle/working/4469.jpg (deflated 1%)
#   adding: kaggle/working/6410.jpg (deflated 0%)
#   adding: kaggle/working/4699.jpg (deflated 0%)
#   adding: kaggle/working/832.jpg (deflated 0%)
#   adding: kaggle/working/13388.jpg (deflated 0%)
#   adding: kaggle/working/4419.jpg (deflated 0%)
#   adding: kaggle/working/7351.jpg (deflated 1%)
#   adding: kaggle/working/10378.jpg (deflated 0%)
#   adding: kaggle/working/9595.jpg (deflated 2%)
#   adding: kaggle/working/393.jpg (deflated 0%)
#   adding: kaggle/working/9282.jpg (deflated 1%)
#   adding: kaggle/working/5013.jpg (deflated 0%)
#   adding: kaggle/working/68.jpg (deflated 0%)
#   adding: kaggle/working/2442.jpg (deflated 0%)
#   adding: kaggle/working/3675.jpg (deflated 1%)
#   adding: kaggle/working/10907.jpg (deflated 1%)
#   adding: kaggle/working/5234.jpg (deflated 0%)
#   adding: kaggle/working/10248.jpg (deflated 1%)
#   adding: kaggle/working/6341.jpg (deflated 0%)
#   adding: kaggle/working/6426.jpg (deflated 1%)
#   adding: kaggle/working/10914.jpg (deflated 0%)
#   adding: kaggle/working/12596.jpg (deflated 0%)
#   adding: kaggle/working/3652.jpg (deflated 2%)
#   adding: kaggle/working/12557.jpg (deflated 7%)
#   adding: kaggle/working/9516.jpg (deflated 1%)
#   adding: kaggle/working/11809.jpg (deflated 1%)
#   adding: kaggle/working/3285.jpg (deflated 0%)
#   adding: kaggle/working/12595.jpg (deflated 1%)
#   adding: kaggle/working/8896.jpg (deflated 0%)
#   adding: kaggle/working/1546.jpg (deflated 0%)
#   adding: kaggle/working/13726.jpg (deflated 0%)
#   adding: kaggle/working/3832.jpg (deflated 0%)
#   adding: kaggle/working/5791.jpg (deflated 0%)
#   adding: kaggle/working/12808.jpg (deflated 0%)
#   adding: kaggle/working/1346.jpg (deflated 2%)
#   adding: kaggle/working/6558.jpg (deflated 1%)
#   adding: kaggle/working/11780.jpg (deflated 0%)
#   adding: kaggle/working/3696.jpg (deflated 0%)
#   adding: kaggle/working/6480.jpg (deflated 1%)
#   adding: kaggle/working/4680.jpg (deflated 0%)
#   adding: kaggle/working/1502.jpg (deflated 0%)
#   adding: kaggle/working/858.jpg (deflated 3%)
#   adding: kaggle/working/12773.jpg (deflated 2%)
#   adding: kaggle/working/8006.jpg (deflated 0%)
#   adding: kaggle/working/5521.jpg (deflated 0%)
#   adding: kaggle/working/657.jpg (deflated 1%)
#   adding: kaggle/working/1718.jpg (deflated 1%)
#   adding: kaggle/working/5800.jpg (deflated 0%)
#   adding: kaggle/working/10342.jpg (deflated 0%)
#   adding: kaggle/working/7014.jpg (deflated 0%)
#   adding: kaggle/working/13434.jpg (deflated 0%)
#   adding: kaggle/working/1066.jpg (deflated 0%)
#   adding: kaggle/working/8616.jpg (deflated 0%)
#   adding: kaggle/working/8487.jpg (deflated 0%)
#   adding: kaggle/working/6135.jpg (deflated 1%)
#   adding: kaggle/working/7334.jpg (deflated 0%)
#   adding: kaggle/working/625.jpg (deflated 1%)
#   adding: kaggle/working/7088.jpg (deflated 0%)
#   adding: kaggle/working/3569.jpg (deflated 0%)
#   adding: kaggle/working/1773.jpg (deflated 0%)
#   adding: kaggle/working/13146.jpg (deflated 1%)
#   adding: kaggle/working/10125.jpg (deflated 4%)
#   adding: kaggle/working/11760.jpg (deflated 0%)
#   adding: kaggle/working/8962.jpg (deflated 1%)
#   adding: kaggle/working/13760.jpg (deflated 0%)
#   adding: kaggle/working/10673.jpg (deflated 3%)
#   adding: kaggle/working/1368.jpg (deflated 0%)
#   adding: kaggle/working/1651.jpg (deflated 0%)
#   adding: kaggle/working/11723.jpg (deflated 1%)
#   adding: kaggle/working/10927.jpg (deflated 2%)
#   adding: kaggle/working/2856.jpg (deflated 0%)
#   adding: kaggle/working/10690.jpg (deflated 1%)
#   adding: kaggle/working/1227.jpg (deflated 1%)
#   adding: kaggle/working/12732.jpg (deflated 0%)
#   adding: kaggle/working/11020.jpg (deflated 1%)
#   adding: kaggle/working/4292.jpg (deflated 0%)
#   adding: kaggle/working/4378.jpg (deflated 1%)
#   adding: kaggle/working/6533.jpg (deflated 1%)
#   adding: kaggle/working/5363.jpg (deflated 1%)
#   adding: kaggle/working/6530.jpg (deflated 0%)
#   adding: kaggle/working/7089.jpg (deflated 0%)
#   adding: kaggle/working/5980.jpg (deflated 1%)
#   adding: kaggle/working/12093.jpg (deflated 1%)
#   adding: kaggle/working/2553.jpg (deflated 1%)
#   adding: kaggle/working/5440.jpg (deflated 0%)
#   adding: kaggle/working/2729.jpg (deflated 0%)
#   adding: kaggle/working/7412.jpg (deflated 0%)
#   adding: kaggle/working/3085.jpg (deflated 0%)
#   adding: kaggle/working/10410.jpg (deflated 1%)
#   adding: kaggle/working/10107.jpg (deflated 0%)
#   adding: kaggle/working/1794.jpg (deflated 0%)
#   adding: kaggle/working/11620.jpg (deflated 0%)
#   adding: kaggle/working/9210.jpg (deflated 0%)
#   adding: kaggle/working/8050.jpg (deflated 0%)
#   adding: kaggle/working/11099.jpg (deflated 0%)
#   adding: kaggle/working/9062.jpg (deflated 1%)
#   adding: kaggle/working/3027.jpg (deflated 1%)
#   adding: kaggle/working/8245.jpg (deflated 0%)
#   adding: kaggle/working/6024.jpg (deflated 1%)
#   adding: kaggle/working/10023.jpg (deflated 2%)
#   adding: kaggle/working/4766.jpg (deflated 1%)
#   adding: kaggle/working/5740.jpg (deflated 0%)
#   adding: kaggle/working/2161.jpg (deflated 1%)
#   adding: kaggle/working/4903.jpg (deflated 1%)
#   adding: kaggle/working/11729.jpg (deflated 2%)
#   adding: kaggle/working/10310.jpg (deflated 1%)
#   adding: kaggle/working/12458.jpg (deflated 1%)
#   adding: kaggle/working/11151.jpg (deflated 0%)
#   adding: kaggle/working/7238.jpg (deflated 0%)
#   adding: kaggle/working/7084.jpg (deflated 3%)
#   adding: kaggle/working/5886.jpg (deflated 1%)
#   adding: kaggle/working/2570.jpg (deflated 2%)
#   adding: kaggle/working/1486.jpg (deflated 0%)
#   adding: kaggle/working/10274.jpg (deflated 0%)
#   adding: kaggle/working/11887.jpg (deflated 0%)
#   adding: kaggle/working/13571.jpg (deflated 1%)
#   adding: kaggle/working/13036.jpg (deflated 0%)
#   adding: kaggle/working/5617.jpg (deflated 0%)
#   adding: kaggle/working/10572.jpg (deflated 0%)
#   adding: kaggle/working/94.jpg (deflated 1%)
#   adding: kaggle/working/3847.jpg (deflated 0%)
#   adding: kaggle/working/8492.jpg (deflated 1%)
#   adding: kaggle/working/1401.jpg (deflated 0%)
#   adding: kaggle/working/9951.jpg (deflated 0%)
#   adding: kaggle/working/2680.jpg (deflated 0%)
#   adding: kaggle/working/3318.jpg (deflated 0%)
#   adding: kaggle/working/8566.jpg (deflated 0%)
#   adding: kaggle/working/7775.jpg (deflated 0%)
#   adding: kaggle/working/8776.jpg (deflated 2%)
#   adding: kaggle/working/8163.jpg (deflated 1%)
#   adding: kaggle/working/6707.jpg (deflated 0%)
#   adding: kaggle/working/4560.jpg (deflated 2%)
#   adding: kaggle/working/7355.jpg (deflated 1%)
#   adding: kaggle/working/12627.jpg (deflated 0%)
#   adding: kaggle/working/12354.jpg (deflated 0%)
#   adding: kaggle/working/8588.jpg (deflated 10%)
#   adding: kaggle/working/10975.jpg (deflated 0%)
#   adding: kaggle/working/3619.jpg (deflated 1%)
#   adding: kaggle/working/3779.jpg (deflated 0%)
#   adding: kaggle/working/8390.jpg (deflated 0%)
#   adding: kaggle/working/7512.jpg (deflated 0%)
#   adding: kaggle/working/4509.jpg (deflated 0%)
#   adding: kaggle/working/2135.jpg (deflated 1%)
#   adding: kaggle/working/6077.jpg (deflated 1%)
#   adding: kaggle/working/2390.jpg (deflated 4%)
#   adding: kaggle/working/6717.jpg (deflated 1%)
#   adding: kaggle/working/13405.jpg (deflated 2%)
#   adding: kaggle/working/11694.jpg (deflated 0%)
#   adding: kaggle/working/10011.jpg (deflated 2%)
#   adding: kaggle/working/11133.jpg (deflated 1%)
#   adding: kaggle/working/5587.jpg (deflated 0%)
#   adding: kaggle/working/4810.jpg (deflated 0%)
#   adding: kaggle/working/6830.jpg (deflated 1%)
#   adding: kaggle/working/3247.jpg (deflated 1%)
#   adding: kaggle/working/9783.jpg (deflated 0%)
#   adding: kaggle/working/10839.jpg (deflated 0%)
#   adding: kaggle/working/8368.jpg (deflated 1%)
#   adding: kaggle/working/1850.jpg (deflated 1%)
#   adding: kaggle/working/3572.jpg (deflated 0%)
# ...
#   adding: kaggle/working/9427.jpg (deflated 1%)
#   adding: kaggle/working/1061.jpg (deflated 1%)
#   adding: kaggle/working/8941.jpg (deflated 8%)
#   adding: kaggle/working/10465.jpg (deflated 0%)
#   adding: kaggle/working/13545.jpg (deflated 0%)
#   adding: kaggle/working/6733.jpg (deflated 0%)
#   adding: kaggle/working/5114.jpg (deflated 1%)
#   adding: kaggle/working/10879.jpg (deflated 0%)
#   adding: kaggle/working/4468.jpg (deflated 0%)
#   adding: kaggle/working/1663.jpg (deflated 1%)
#   adding: kaggle/working/6718.jpg (deflated 1%)
#   adding: kaggle/working/8038.jpg (deflated 1%)
#   adding: kaggle/working/3720.jpg (deflated 0%)
#   adding: kaggle/working/6969.jpg (deflated 1%)
#   adding: kaggle/working/9868.jpg (deflated 0%)
#   adding: kaggle/working/9761.jpg (deflated 1%)
#   adding: kaggle/working/9843.jpg (deflated 1%)
#   adding: kaggle/working/2696.jpg (deflated 0%)
#   adding: kaggle/working/4504.jpg (deflated 0%)
#   adding: kaggle/working/12112.jpg (deflated 1%)
#   adding: kaggle/working/13673.jpg (deflated 0%)
#   adding: kaggle/working/5606.jpg (deflated 0%)
#   adding: kaggle/working/7717.jpg (deflated 0%)
#   adding: kaggle/working/2834.jpg (deflated 1%)
#   adding: kaggle/working/2445.jpg (deflated 0%)
#   adding: kaggle/working/12047.jpg (deflated 0%)
#   adding: kaggle/working/4681.jpg (deflated 1%)
#   adding: kaggle/working/9724.jpg (deflated 0%)
#   adding: kaggle/working/250.jpg (deflated 2%)
#   adding: kaggle/working/4591.jpg (deflated 10%)
#   adding: kaggle/working/5783.jpg (deflated 2%)
#   adding: kaggle/working/13000.jpg (deflated 1%)
#   adding: kaggle/working/2901.jpg (deflated 1%)
#   adding: kaggle/working/554.jpg (deflated 1%)
#   adding: kaggle/working/6541.jpg (deflated 0%)
#   adding: kaggle/working/7066.jpg (deflated 0%)
#   adding: kaggle/working/9504.jpg (deflated 1%)
#   adding: kaggle/working/3415.jpg (deflated 5%)
#   adding: kaggle/working/3005.jpg (deflated 0%)
#   adding: kaggle/working/10281.jpg (deflated 0%)
#   adding: kaggle/working/4683.jpg (deflated 0%)
#   adding: kaggle/working/3623.jpg (deflated 0%)
#   adding: kaggle/working/12510.jpg (deflated 1%)
#   adding: kaggle/working/4789.jpg (deflated 0%)
#   adding: kaggle/working/11494.jpg (deflated 0%)
#   adding: kaggle/working/4099.jpg (deflated 1%)
#   adding: kaggle/working/5671.jpg (deflated 0%)
#   adding: kaggle/working/10994.jpg (deflated 0%)
#   adding: kaggle/working/10369.jpg (deflated 0%)
#   adding: kaggle/working/7206.jpg (deflated 0%)
#   adding: kaggle/working/10240.jpg (deflated 1%)
#   adding: kaggle/working/11250.jpg (deflated 0%)
#   adding: kaggle/working/9906.jpg (deflated 1%)
#   adding: kaggle/working/356.jpg (deflated 1%)
#   adding: kaggle/working/3776.jpg (deflated 0%)
#   adding: kaggle/working/3804.jpg (deflated 1%)
#   adding: kaggle/working/2488.jpg (deflated 1%)
#   adding: kaggle/working/11668.jpg (deflated 0%)
#   adding: kaggle/working/4389.jpg (deflated 1%)
#   adding: kaggle/working/9671.jpg (deflated 2%)
#   adding: kaggle/working/7509.jpg (deflated 3%)
#   adding: kaggle/working/5799.jpg (deflated 1%)
#   adding: kaggle/working/10607.jpg (deflated 1%)
#   adding: kaggle/working/62.jpg (deflated 10%)
#   adding: kaggle/working/7547.jpg (deflated 1%)
#   adding: kaggle/working/433.jpg (deflated 0%)
#   adding: kaggle/working/2349.jpg (deflated 1%)
#   adding: kaggle/working/713.jpg (deflated 0%)
#   adding: kaggle/working/7217.jpg (deflated 0%)
#   adding: kaggle/working/3087.jpg (deflated 0%)
#   adding: kaggle/working/11713.jpg (deflated 0%)
#   adding: kaggle/working/10215.jpg (deflated 1%)
#   adding: kaggle/working/6836.jpg (deflated 0%)
#   adding: kaggle/working/3829.jpg (deflated 0%)
#   adding: kaggle/working/11322.jpg (deflated 1%)
#   adding: kaggle/working/1331.jpg (deflated 0%)
#   adding: kaggle/working/4933.jpg (deflated 1%)
#   adding: kaggle/working/9109.jpg (deflated 1%)
#   adding: kaggle/working/7072.jpg (deflated 1%)
#   adding: kaggle/working/13028.jpg (deflated 1%)
#   adding: kaggle/working/12556.jpg (deflated 1%)
#   adding: kaggle/working/5179.jpg (deflated 0%)
#   adding: kaggle/working/11512.jpg (deflated 1%)
#   adding: kaggle/working/128.jpg (deflated 0%)
#   adding: kaggle/working/11636.jpg (deflated 0%)
#   adding: kaggle/working/685.jpg (deflated 1%)
#   adding: kaggle/working/12051.jpg (deflated 0%)
#   adding: kaggle/working/6045.jpg (deflated 1%)
#   adding: kaggle/working/11283.jpg (deflated 1%)
#   adding: kaggle/working/1506.jpg (deflated 0%)
#   adding: kaggle/working/9459.jpg (deflated 0%)
#   adding: kaggle/working/2208.jpg (deflated 1%)
#   adding: kaggle/working/13416.jpg (deflated 1%)
#   adding: kaggle/working/12135.jpg (deflated 2%)
#   adding: kaggle/working/219.jpg (deflated 0%)
#   adding: kaggle/working/4748.jpg (deflated 0%)
#   adding: kaggle/working/3953.jpg (deflated 1%)
#   adding: kaggle/working/11879.jpg (deflated 1%)
#   adding: kaggle/working/10286.jpg (deflated 1%)
#   adding: kaggle/working/2569.jpg (deflated 1%)
#   adding: kaggle/working/6431.jpg (deflated 0%)
#   adding: kaggle/working/2163.jpg (deflated 0%)
#   adding: kaggle/working/9343.jpg (deflated 2%)
#   adding: kaggle/working/12040.jpg (deflated 1%)
#   adding: kaggle/working/108.jpg (deflated 0%)
#   adding: kaggle/working/8113.jpg (deflated 0%)
#   adding: kaggle/working/4546.jpg (deflated 10%)
#   adding: kaggle/working/13420.jpg (deflated 0%)
#   adding: kaggle/working/11192.jpg (deflated 0%)
#   adding: kaggle/working/9585.jpg (deflated 1%)
#   adding: kaggle/working/6693.jpg (deflated 1%)
#   adding: kaggle/working/2502.jpg (deflated 1%)
#   adding: kaggle/working/5401.jpg (deflated 1%)
#   adding: kaggle/working/6328.jpg (deflated 0%)
#   adding: kaggle/working/5651.jpg (deflated 1%)
#   adding: kaggle/working/6176.jpg (deflated 0%)
#   adding: kaggle/working/6393.jpg (deflated 0%)
#   adding: kaggle/working/12652.jpg (deflated 0%)
#   adding: kaggle/working/5436.jpg (deflated 0%)
#   adding: kaggle/working/4696.jpg (deflated 1%)
#   adding: kaggle/working/5935.jpg (deflated 0%)
#   adding: kaggle/working/3511.jpg (deflated 0%)
#   adding: kaggle/working/3031.jpg (deflated 0%)
#   adding: kaggle/working/2529.jpg (deflated 0%)
#   adding: kaggle/working/2277.jpg (deflated 0%)
#   adding: kaggle/working/11498.jpg (deflated 1%)
#   adding: kaggle/working/12270.jpg (deflated 0%)
#   adding: kaggle/working/11704.jpg (deflated 0%)
#   adding: kaggle/working/9802.jpg (deflated 1%)
#   adding: kaggle/working/4399.jpg (deflated 0%)
#   adding: kaggle/working/13223.jpg (deflated 0%)
#   adding: kaggle/working/3312.jpg (deflated 0%)
#   adding: kaggle/working/29.jpg (deflated 1%)
#   adding: kaggle/working/7348.jpg (deflated 1%)
#   adding: kaggle/working/10276.jpg (deflated 0%)
#   adding: kaggle/working/11667.jpg (deflated 1%)
#   adding: kaggle/working/6441.jpg (deflated 1%)
#   adding: kaggle/working/5516.jpg (deflated 1%)
#   adding: kaggle/working/6609.jpg (deflated 0%)
#   adding: kaggle/working/617.jpg (deflated 0%)
#   adding: kaggle/working/8325.jpg (deflated 0%)
#   adding: kaggle/working/3076.jpg (deflated 0%)
#   adding: kaggle/working/13492.jpg (deflated 0%)
#   adding: kaggle/working/2427.jpg (deflated 0%)
#   adding: kaggle/working/8264.jpg (deflated 1%)
#   adding: kaggle/working/1414.jpg (deflated 1%)
#   adding: kaggle/working/3548.jpg (deflated 0%)
#   adding: kaggle/working/9091.jpg (deflated 0%)
#   adding: kaggle/working/3742.jpg (deflated 0%)
#   adding: kaggle/working/10515.jpg (deflated 0%)
#   adding: kaggle/working/11610.jpg (deflated 2%)
#   adding: kaggle/working/1949.jpg (deflated 1%)
#   adding: kaggle/working/9287.jpg (deflated 0%)
#   adding: kaggle/working/14.jpg (deflated 0%)
#   adding: kaggle/working/12710.jpg (deflated 0%)
#   adding: kaggle/working/2926.jpg (deflated 0%)
#   adding: kaggle/working/6183.jpg (deflated 4%)
#   adding: kaggle/working/11614.jpg (deflated 1%)
#   adding: kaggle/working/9673.jpg (deflated 0%)
#   adding: kaggle/working/13218.jpg (deflated 1%)
#   adding: kaggle/working/7257.jpg (deflated 0%)
#   adding: kaggle/working/1880.jpg (deflated 1%)
#   adding: kaggle/working/666.jpg (deflated 1%)
#   adding: kaggle/working/7469.jpg (deflated 2%)
#   adding: kaggle/working/6234.jpg (deflated 1%)
#   adding: kaggle/working/7769.jpg (deflated 0%)
#   adding: kaggle/working/1968.jpg (deflated 1%)
#   adding: kaggle/working/6840.jpg (deflated 1%)
#   adding: kaggle/working/2457.jpg (deflated 0%)
#   adding: kaggle/working/9204.jpg (deflated 1%)
#   adding: kaggle/working/10670.jpg (deflated 1%)
#   adding: kaggle/working/9252.jpg (deflated 0%)
#   adding: kaggle/working/13708.jpg (deflated 1%)
#   adding: kaggle/working/2077.jpg (deflated 0%)
#   adding: kaggle/working/1168.jpg (deflated 2%)
#   adding: kaggle/working/11775.jpg (deflated 0%)
#   adding: kaggle/working/3812.jpg (deflated 1%)
#   adding: kaggle/working/2923.jpg (deflated 0%)
#   adding: kaggle/working/11570.jpg (deflated 7%)
#   adding: kaggle/working/5507.jpg (deflated 0%)
#   adding: kaggle/working/4734.jpg (deflated 0%)
#   adding: kaggle/working/5361.jpg (deflated 0%)
#   adding: kaggle/working/9438.jpg (deflated 1%)
#   adding: kaggle/working/8655.jpg (deflated 0%)
#   adding: kaggle/working/6864.jpg (deflated 2%)
#   adding: kaggle/working/2737.jpg (deflated 0%)
#   adding: kaggle/working/12473.jpg (deflated 0%)
#   adding: kaggle/working/12124.jpg (deflated 2%)
#   adding: kaggle/working/2788.jpg (deflated 1%)
#   adding: kaggle/working/9670.jpg (deflated 1%)
#   adding: kaggle/working/7971.jpg (deflated 0%)
#   adding: kaggle/working/2044.jpg (deflated 1%)
#   adding: kaggle/working/3658.jpg (deflated 1%)
#   adding: kaggle/working/11275.jpg (deflated 2%)
#   adding: kaggle/working/7397.jpg (deflated 0%)
#   adding: kaggle/working/7264.jpg (deflated 0%)
#   adding: kaggle/working/3520.jpg (deflated 0%)
#   adding: kaggle/working/194.jpg (deflated 1%)
#   adding: kaggle/working/13739.jpg (deflated 2%)
#   adding: kaggle/working/8434.jpg (deflated 0%)
#   adding: kaggle/working/9639.jpg (deflated 1%)
#   adding: kaggle/working/7843.jpg (deflated 0%)
#   adding: kaggle/working/5698.jpg (deflated 1%)
#   adding: kaggle/working/10398.jpg (deflated 0%)
#   adding: kaggle/working/10689.jpg (deflated 1%)
#   adding: kaggle/working/8380.jpg (deflated 1%)
#   adding: kaggle/working/5801.jpg (deflated 1%)
#   adding: kaggle/working/10487.jpg (deflated 0%)
#   adding: kaggle/working/2137.jpg (deflated 2%)
#   adding: kaggle/working/3386.jpg (deflated 0%)
#   adding: kaggle/working/6110.jpg (deflated 1%)
#   adding: kaggle/working/3411.jpg (deflated 0%)
#   adding: kaggle/working/6869.jpg (deflated 0%)
#   adding: kaggle/working/7597.jpg (deflated 1%)
#   adding: kaggle/working/6617.jpg (deflated 0%)
#   adding: kaggle/working/8581.jpg (deflated 1%)
#   adding: kaggle/working/9627.jpg (deflated 2%)
#   adding: kaggle/working/12299.jpg (deflated 1%)
#   adding: kaggle/working/10928.jpg (deflated 1%)
#   adding: kaggle/working/9716.jpg (deflated 1%)
#   adding: kaggle/working/5498.jpg (deflated 1%)
#   adding: kaggle/working/10202.jpg (deflated 0%)
#   adding: kaggle/working/3032.jpg (deflated 0%)
#   adding: kaggle/working/3998.jpg (deflated 0%)
#   adding: kaggle/working/3510.jpg (deflated 4%)
#   adding: kaggle/working/5400.jpg (deflated 0%)
#   adding: kaggle/working/8573.jpg (deflated 0%)
#   adding: kaggle/working/6529.jpg (deflated 0%)
#   adding: kaggle/working/11658.jpg (deflated 0%)
#   adding: kaggle/working/3058.jpg (deflated 0%)
#   adding: kaggle/working/1195.jpg (deflated 1%)
#   adding: kaggle/working/527.jpg (deflated 1%)
#   adding: kaggle/working/11089.jpg (deflated 0%)
#   adding: kaggle/working/6412.jpg (deflated 1%)
#   adding: kaggle/working/10940.jpg (deflated 0%)
#   adding: kaggle/working/2657.jpg (deflated 0%)
#   adding: kaggle/working/10799.jpg (deflated 1%)
#   adding: kaggle/working/5978.jpg (deflated 0%)
#   adding: kaggle/working/473.jpg (deflated 0%)
#   adding: kaggle/working/7916.jpg (deflated 1%)
#   adding: kaggle/working/6218.jpg (deflated 1%)
#   adding: kaggle/working/13599.jpg (deflated 1%)
#   adding: kaggle/working/5880.jpg (deflated 1%)
#   adding: kaggle/working/6746.jpg (deflated 1%)
#   adding: kaggle/working/3437.jpg (deflated 0%)
#   adding: kaggle/working/12813.jpg (deflated 0%)
#   adding: kaggle/working/8129.jpg (deflated 0%)
#   adding: kaggle/working/8940.jpg (deflated 2%)
#   adding: kaggle/working/13458.jpg (deflated 1%)
#   adding: kaggle/working/4876.jpg (deflated 1%)
#   adding: kaggle/working/6959.jpg (deflated 0%)
#   adding: kaggle/working/7808.jpg (deflated 1%)
#   adding: kaggle/working/6905.jpg (deflated 4%)
#   adding: kaggle/working/10646.jpg (deflated 1%)
#   adding: kaggle/working/11168.jpg (deflated 0%)
#   adding: kaggle/working/4806.jpg (deflated 2%)
#   adding: kaggle/working/7564.jpg (deflated 1%)
#   adding: kaggle/working/4359.jpg (deflated 0%)
#   adding: kaggle/working/218.jpg (deflated 1%)
#   adding: kaggle/working/6037.jpg (deflated 1%)
#   adding: kaggle/working/5191.jpg (deflated 0%)
#   adding: kaggle/working/12176.jpg (deflated 2%)
#   adding: kaggle/working/7398.jpg (deflated 0%)
#   adding: kaggle/working/8187.jpg (deflated 0%)
#   adding: kaggle/working/6361.jpg (deflated 0%)
#   adding: kaggle/working/3050.jpg (deflated 0%)
#   adding: kaggle/working/9469.jpg (deflated 0%)
#   adding: kaggle/working/2628.jpg (deflated 0%)
#   adding: kaggle/working/8612.jpg (deflated 1%)
#   adding: kaggle/working/5081.jpg (deflated 0%)
#   adding: kaggle/working/7877.jpg (deflated 0%)
#   adding: kaggle/working/1359.jpg (deflated 0%)
#   adding: kaggle/working/3035.jpg (deflated 0%)
#   adding: kaggle/working/6326.jpg (deflated 2%)
#   adding: kaggle/working/553.jpg (deflated 1%)
#   adding: kaggle/working/11433.jpg (deflated 1%)
#   adding: kaggle/working/8718.jpg (deflated 1%)
#   adding: kaggle/working/2471.jpg (deflated 0%)
#   adding: kaggle/working/1581.jpg (deflated 1%)
#   adding: kaggle/working/10185.jpg (deflated 0%)
#   adding: kaggle/working/6941.jpg (deflated 1%)
#   adding: kaggle/working/4595.jpg (deflated 0%)
#   adding: kaggle/working/4211.jpg (deflated 1%)
#   adding: kaggle/working/8150.jpg (deflated 0%)
#   adding: kaggle/working/4889.jpg (deflated 0%)
#   adding: kaggle/working/13742.jpg (deflated 0%)
#   adding: kaggle/working/1531.jpg (deflated 0%)
#   adding: kaggle/working/507.jpg (deflated 0%)
#   adding: kaggle/working/13196.jpg (deflated 1%)
#   adding: kaggle/working/5737.jpg (deflated 0%)
#   adding: kaggle/working/1485.jpg (deflated 0%)
#   adding: kaggle/working/4821.jpg (deflated 0%)
#   adding: kaggle/working/2431.jpg (deflated 0%)
#   adding: kaggle/working/10913.jpg (deflated 0%)
#   adding: kaggle/working/9877.jpg (deflated 0%)
#   adding: kaggle/working/822.jpg (deflated 0%)
#   adding: kaggle/working/9931.jpg (deflated 0%)
#   adding: kaggle/working/6472.jpg (deflated 1%)
#   adding: kaggle/working/187.jpg (deflated 1%)
#   adding: kaggle/working/13145.jpg (deflated 0%)
#   adding: kaggle/working/9707.jpg (deflated 1%)
#   adding: kaggle/working/436.jpg (deflated 1%)
#   adding: kaggle/working/12731.jpg (deflated 0%)
#   adding: kaggle/working/10584.jpg (deflated 1%)
#   adding: kaggle/working/11290.jpg (deflated 1%)
#   adding: kaggle/working/8583.jpg (deflated 0%)
#   adding: kaggle/working/12325.jpg (deflated 0%)
#   adding: kaggle/working/13694.jpg (deflated 2%)
#   adding: kaggle/working/3265.jpg (deflated 1%)
#   adding: kaggle/working/13478.jpg (deflated 0%)
#   adding: kaggle/working/10951.jpg (deflated 0%)
#   adding: kaggle/working/13240.jpg (deflated 1%)
#   adding: kaggle/working/1002.jpg (deflated 0%)
#   adding: kaggle/working/2955.jpg (deflated 0%)
#   adding: kaggle/working/8903.jpg (deflated 1%)
#   adding: kaggle/working/32.jpg (deflated 1%)
#   adding: kaggle/working/2913.jpg (deflated 1%)
#   adding: kaggle/working/1978.jpg (deflated 0%)
#   adding: kaggle/working/12228.jpg (deflated 0%)
#   adding: kaggle/working/8990.jpg (deflated 1%)
#   adding: kaggle/working/1904.jpg (deflated 2%)
#   adding: kaggle/working/797.jpg (deflated 0%)
#   adding: kaggle/working/13397.jpg (deflated 0%)
#   adding: kaggle/working/8202.jpg (deflated 1%)
#   adding: kaggle/working/10520.jpg (deflated 5%)
#   adding: kaggle/working/5656.jpg (deflated 0%)
#   adding: kaggle/working/3313.jpg (deflated 0%)
#   adding: kaggle/working/5004.jpg (deflated 0%)
#   adding: kaggle/working/7237.jpg (deflated 2%)
#   adding: kaggle/working/12015.jpg (deflated 0%)
#   adding: kaggle/working/143.jpg (deflated 1%)
#   adding: kaggle/working/3061.jpg (deflated 8%)

# %%
FileLink(r'crop_image_80.zip')
# Out:
# /kaggle/working/crop_image_80.zip

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
df = pd.read_csv("/kaggle/input/d/neetnetnet/label-face/labels.csv", index_col = None)
df.head()
# Out:
#        file_name  height  width  \
# 0  100013282.jpg    1333   2000
# 1  100016175.jpg    1333   2000
# 2   10004189.jpg    2000   1333
# 3  100104575.jpg    1333   2000
# 4  100104600.jpg    2000   1333
#
#                                                 bbox     age       race  \
# 0  [934.0000000000097, 144.82228672769534, 238.24...  20-30s  Caucasian
# 1  [1094.0513571635438, 422.91772295627203, 55.45...  20-30s  Caucasian
# 2  [419.93871061403877, 269.1250391680045, 377.19...  20-30s  Mongoloid
# 3  [1490.6909678848915, 676.0000000000097, 37.553...  20-30s  Caucasian
# 4  [549.169724453414, 92.52040334013152, 306.8821...  20-30s  Caucasian
#
#      masked   skintone    emotion  gender
# 0  unmasked  mid-light    Neutral    Male
# 1  unmasked      light    Neutral    Male
# 2  unmasked      light  Happiness  Female
# 3  unmasked  mid-light    Neutral    Male
# 4  unmasked  mid-light  Happiness  Female

# %%
age_classes = {"Baby" : 0, "Kid" : 1, "Teenager" : 2, "20-30s" : 3, "40-50s" : 4, "Senior" : 5}
gender_classes = {
    label : idx for idx,label in enumerate(df["gender"].unique())
}
emotion_classes = {
    label : idx for idx,label in enumerate(df["emotion"].unique())
}
masked_classes = {
    label : idx for idx,label in enumerate(df["masked"].unique())
}
race_classes = {
    label : idx for idx,label in enumerate(df["race"].unique())
}
skintone_classes = {
    label : idx for idx,label in enumerate(df["skintone"].unique())
}
print(age_classes)
print(gender_classes)
print(emotion_classes)
print(masked_classes)
print(race_classes)
print(skintone_classes)
# Out:
# {'Baby': 0, 'Kid': 1, 'Teenager': 2, '20-30s': 3, '40-50s': 4, 'Senior': 5}
# {'Male': 0, 'Female': 1}
# {'Neutral': 0, 'Happiness': 1, 'Anger': 2, 'Surprise': 3, 'Fear': 4, 'Sadness': 5, 'Disgust': 6}
# {'unmasked': 0, 'masked': 1}
# {'Caucasian': 0, 'Mongoloid': 1, 'Negroid': 2}
# {'mid-light': 0, 'light': 1, 'mid-dark': 2, 'dark': 3}

# %% [markdown]
# * **Data train**

# %%
img_paths = []
age_las = []
gender_las = []
emotion_las = []
masked_las = []
race_las = []
skintone_las = []
mask_img_paths = []
root_dir = "/kaggle/input/crop-image"

for i in range(len(df)):
    img_paths.append(os.path.join(root_dir,df.loc[i,"file_name"]))
    mask_img_paths.append(os.path.join(root_dir,df.loc[i,"file_name"]))
    age_las.append(df.loc[i,"age"])
    gender_las.append(df.loc[i,"gender"])
    emotion_las.append(df.loc[i,"emotion"])
    masked_las.append(df.loc[i,"masked"])
    race_las.append(df.loc[i,"race"])
    skintone_las.append(df.loc[i,"skintone"])

age_labels = [age_classes[i] for i in age_las]
gender_labels = [gender_classes[i] for i in gender_las]
emotion_labels = [emotion_classes[i] for i in emotion_las]
masked_labels = [masked_classes[i] for i in masked_las]
race_labels = [race_classes[i] for i in race_las]
skintone_labels = [skintone_classes[i] for i in skintone_las]

# %% [markdown]
# * **Data Test 20%**

# %%
test_img_paths = [os.path.join("/kaggle/input/test-img-crop/kaggle/working",i) for i in os.listdir("/kaggle/input/test-img-crop/kaggle/working") ]
img_names = [i for i in os.listdir("/kaggle/input/test-img-crop/kaggle/working")]

# %% [markdown]
# * **Data Test 80%**

# %%
test_img_paths = [os.path.join("/kaggle/input/crop-img-test-80/kaggle/working",i) for i in os.listdir("/kaggle/input/crop-img-test-80/kaggle/working") ]
img_names = [i for i in os.listdir("/kaggle/input/crop-img-test-80/kaggle/working")]

# %%
class TrainDataset(Dataset):
    def __init__(
        self, X, y, 
        transform
    ):
        self.transform = transform
        self.img_paths = X
        self.labels = y
    
    def __len__(self):
        return len(self.img_paths)
    
    def __getitem__(self,idx):
        img_path = self.img_paths[idx]
        img = Image.open(img_path).convert("RGB")
        label = self.labels[idx]
        
        img = self.transform(img)
        
        return img,label

# %%
class TestDataset(Dataset):
    def __init__(
        self, X, y, 
        transform
    ):
        self.transform = transform
        self.img_paths = X
        self.names = y
    
    def __len__(self):
        return len(self.img_paths)
    
    def __getitem__(self,idx):
        img_path = self.img_paths[idx]
        img = Image.open(img_path).convert("RGB")
        name = self.names[idx]
        
        img = self.transform(img)
        
        return img,name

# %% [markdown]
# # **Age Model**

# %%
seed = 42
val_size = 0.3
is_shuffle = True
X_train_age, X_val_age, y_train_age, y_val_age = train_test_split(
    img_paths, age_labels, 
    test_size = val_size, 
    random_state = seed,
    shuffle = is_shuffle
)

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(5),
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.75,
                             scale=(0.01, 0.3),
                             ratio=(1.0, 1.0),
                             value=0,
                             inplace =True)      
])

val_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
age_train_dataset = TrainDataset(
    X_train_age, y_train_age,
    transform = train_transform
)

age_val_dataset = TrainDataset(
    X_val_age, y_val_age,
    transform = val_transform
)

# %%
train_batch_size = 64
val_batch_size = 64

age_train_loader = DataLoader(
    age_train_dataset,
    batch_size = train_batch_size,
    shuffle = True
) 

age_val_loader = DataLoader(
    age_val_dataset,
    batch_size = val_batch_size,
    shuffle = False
)

# %%
def evaluation(model,val_loader,criterion):
    model.eval()
    val_loss = 0.0
    running_correct = 0 
    total = 0 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs,labels)
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs.data,1)
            total += labels.size(0)
            running_correct += (predicted == labels).sum().item()
    
    accuracy = 100 * running_correct / total
    val_loss = val_loss / len(val_loader)
    return val_loss, accuracy

# %%
def save(filename, model):
    filename = "/kaggle/working/" + filename
    torch.save(model.state_dict(), filename)
    print("Saved model as", filename)

# %% [markdown]
# * **Age model**

# %%
age_model = InceptionResnetV1(pretrained='vggface2',
                              device=device,
                              classify= True,
                              num_classes=len(age_classes))
# Out:
#   0%|          | 0.00/107M [00:00<?, ?B/s]

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(age_model.parameters(),
                             lr= 1e-4)

# %% [markdown]
# * **Train age model**

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
max_epoch = 50
best_accuracy = 50

for epoch in range(max_epoch):
    age_model.train()
    running_loss = 0.0
    running_correct = 0   
    total = 0             
    print(f"Epoch {epoch + 1}: ", end='')
    
    for _ in tqdm(range(len(age_train_loader))):
        inputs, labels = next(iter(age_train_loader))
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = age_model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()  
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()
    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    val_loss, val_accuracy = evaluation(age_model, age_val_loader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")
    if val_accuracy > best_accuracy:
        print("saving at epoch", epoch+1)
        best_accuracy = val_accuracy
        save("age_weight.pt", age_model)
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

# %% [markdown]
# * **Plot age model**

# %%
plt.plot(train_losses, label='train_losses')
plt.plot(val_losses, label='val_losses')
plt.legend()

# %%
plt.plot(train_accuracies, label='train_accuracy')
plt.plot(val_accuracies, label='val_accuracy')
plt.legend()

# %% [markdown]
# * **Predict age model**

# %%
age_model.load_state_dict(torch.load("/kaggle/input/age-weight-1/age_weight.pt"))
age_model.to(device)
# Out:
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=6, bias=True)
# )

# %%
reverse_age = ['Baby', 'Kid', 'Teenager', '20-30s', '40-50s', 'Senior']

# %%
test_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
test_dataset = TestDataset(
    test_img_paths, img_names,
    transform = test_transform
)

# %%
test_batch_size = 64
test_loader = DataLoader(
    test_dataset,
    batch_size = test_batch_size,
    shuffle = False
)

# %%
age_submiss = {}
age_model.eval()
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = age_model(images)
        _, predicted = torch.max(outputs.data,1)
        for predict, name in zip(predicted, names):
            age_submiss[name[:-4]] = reverse_age[predict]

# %% [markdown]
# # **Mask Model**

# %% [markdown]
# * **Add with mask data from** https://www.kaggle.com/datasets/ashishjangra27/face-mask-12k-images-dataset

# %%
for img in os.listdir("/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithMask"):
    mask_img_paths.append(os.path.join("/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test/WithMask",img))
    masked_labels.append(1)

for img in os.listdir("/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask"):
    mask_img_paths.append(os.path.join("/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask",img))
    masked_labels.append(1)
    
for img in os.listdir("/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask"):
    mask_img_paths.append(os.path.join("/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask",img))
    masked_labels.append(1)

# %%
len(mask_img_paths)

# %%
seed = 42
val_size = 0.3
is_shuffle = True
X_train_mask, X_val_mask, y_train_mask, y_val_mask = train_test_split(
    mask_img_paths, masked_labels, 
    test_size = val_size, 
    random_state = seed,
    shuffle = is_shuffle
)

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(5),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.75,
                             scale=(0.01, 0.3),
                             ratio=(1.0, 1.0),
                             value=0,
                             inplace =True)      
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
mask_train_dataset = TrainDataset(
    X_train_mask, y_train_mask,
    transform = train_transform
)

mask_val_dataset = TrainDataset(
    X_val_mask, y_val_mask,
    transform = val_transform
)

# %%
train_batch_size = 64
val_batch_size = 64

mask_train_loader = DataLoader(
    mask_train_dataset,
    batch_size = train_batch_size,
    shuffle = True
) 

mask_val_loader = DataLoader(
    mask_val_dataset,
    batch_size = val_batch_size,
    shuffle = False
)

# %%
def evaluation(model,val_loader,criterion):
    model.eval()
    val_loss = 0.0
    running_correct = 0 
    total = 0 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs,labels)
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs.data,1)
            total += labels.size(0)
            running_correct += (predicted == labels).sum().item()
    
    accuracy = 100 * running_correct / total
    val_loss = val_loss / len(val_loader)
    return val_loss, accuracy

# %%
def save(filename, model):
    filename = "/kaggle/working/" + filename
    torch.save(model.state_dict(), filename)
    print("Saved model as", filename)

# %% [markdown]
# * **Mask model**

# %%
mask_model = InceptionResnetV1(pretrained='vggface2',
                              device=device,
                              classify= True,
                              num_classes=2)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(mask_model.parameters(),
                             lr= 1e-4)

# %% [markdown]
# * **Train mask model**

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
max_epoch = 50
best_accuracy = 50
for epoch in range(max_epoch):
    mask_model.train()
    running_loss = 0.0
    running_correct = 0   
    total = 0             
    print(f"Epoch {epoch + 1}: ", end='')
    
    for _ in tqdm(range(len(mask_train_loader))):
        inputs, labels = next(iter(mask_train_loader))
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = mask_model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()  
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()
    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    val_loss, val_accuracy = evaluation(mask_model, mask_val_loader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")
    if val_accuracy > best_accuracy:
        print("saving at epoch", epoch+1)
        best_accuracy = val_accuracy
        save("mask_weight.pt", mask_model)
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

# %% [markdown]
# * **Plot mask model**

# %%
plt.plot(train_losses, label='train_losses')
plt.plot(val_losses, label='val_losses')
plt.legend()

# %%
plt.plot(train_accuracies, label='train_accuracy')
plt.plot(val_accuracies, label='val_accuracy')
plt.legend()

# %% [markdown]
# * **Predict mask model**

# %%
mask_model.load_state_dict(torch.load("/kaggle/input/weight-mask/mask_weight.pt"))
mask_model.to(device)
# Out:
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
reverse_mask = ['unmasked', 'masked']

# %%
test_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
test_dataset = TestDataset(
    test_img_paths, img_names,
    transform = test_transform
)

# %%
test_batch_size = 64
test_loader = DataLoader(
    test_dataset,
    batch_size = test_batch_size,
    shuffle = False
)

# %%
mask_submiss = {}
mask_model.eval()
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = mask_model(images)
        _, predicted = torch.max(outputs.data,1)
        for predict, name in zip(predicted, names):
            mask_submiss[name[:-4]] = reverse_mask[predict]

# %% [markdown]
# # **Skintone model**

# %%
seed = 42
val_size = 0.3
is_shuffle = True
X_train_skintone, X_val_skintone, y_train_skintone, y_val_skintone = train_test_split(
    img_paths, skintone_labels, 
    test_size = val_size, 
    random_state = seed,
    shuffle = is_shuffle
)

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(5),
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.75,
                             scale=(0.01, 0.3),
                             ratio=(1.0, 1.0),
                             value=0,
                             inplace =True)      
])

val_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
skintone_train_dataset = TrainDataset(
    X_train_skintone, y_train_skintone,
    transform = train_transform
)

skintone_val_dataset = TrainDataset(
    X_val_skintone, y_val_skintone,
    transform = val_transform
)

# %%
train_batch_size = 64
val_batch_size = 64

skintone_train_loader = DataLoader(
    skintone_train_dataset,
    batch_size = train_batch_size,
    shuffle = True
) 

skintone_val_loader = DataLoader(
    skintone_val_dataset,
    batch_size = val_batch_size,
    shuffle = False
)

# %%
def evaluation(model,val_loader,criterion):
    model.eval()
    val_loss = 0.0
    running_correct = 0 
    total = 0 
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs,labels)
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs.data,1)
            total += labels.size(0)
            running_correct += (predicted == labels).sum().item()
    
    accuracy = 100 * running_correct / total
    val_loss = val_loss / len(val_loader)
    return val_loss, accuracy

# %%
def save(filename, model):
    filename = "/kaggle/working/" + filename
    torch.save(model.state_dict(), filename)
    print("Saved model as", filename)

# %% [markdown]
# * **Skintone model**

# %%
skintone_model = InceptionResnetV1(pretrained='vggface2',
                              device=device,
                              classify= True,
                              num_classes=len(skintone_classes))

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(skintone_model.parameters(),
                             lr= 1e-4)

# %% [markdown]
# * **Train skintone model**

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
max_epoch = 50
best_accuracy = 50

for epoch in range(max_epoch):
    skintone_model.train()
    running_loss = 0.0
    running_correct = 0   
    total = 0             
    print(f"Epoch {epoch + 1}: ", end='')
    
    for _ in tqdm(range(len(skintone_train_loader))):
        inputs, labels = next(iter(skintone_train_loader))
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = skintone_model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()  
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()
    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    val_loss, val_accuracy = evaluation(skintone_model, skintone_val_loader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")
    if val_accuracy > best_accuracy:
        print("saving at epoch", epoch+1)
        best_accuracy = val_accuracy
        save("skintone_weight.pt", skintone_model)
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

# %% [markdown]
# * **Plot skintone model**

# %%
plt.plot(train_losses, label='train_losses')
plt.plot(val_losses, label='val_losses')
plt.legend()

# %%
plt.plot(train_accuracies, label='train_accuracy')
plt.plot(val_accuracies, label='val_accuracy')
plt.legend()

# %% [markdown]
# * **Predict skintone model**

# %%
skintone_model.load_state_dict(torch.load("/kaggle/input/skintone-weight-1/skintone_weight.pt"))
skintone_model.to(device)
# Out:
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=4, bias=True)
# )

# %%
reverse_skintone = ['mid-light', 'light', 'mid-dark', 'dark']

# %%
test_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
test_dataset = TestDataset(
    test_img_paths, img_names,
    transform = test_transform
)

# %%
test_batch_size = 64
test_loader = DataLoader(
    test_dataset,
    batch_size = test_batch_size,
    shuffle = False
)

# %%
skintone_submiss = {}
skintone_model.eval()
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = skintone_model(images)
        _, predicted = torch.max(outputs.data,1)
        for predict, name in zip(predicted, names):
            skintone_submiss[name[:-4]] = reverse_skintone[predict]

# %% [markdown]
# # **Race model**

# %%
seed = 42
val_size = 0.3
is_shuffle = True
X_train_race, X_val_race, y_train_race, y_val_race = train_test_split(
    img_paths, race_labels, 
    test_size = val_size, 
    random_state = seed,
    shuffle = is_shuffle
)

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(5),
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.75,
                             scale=(0.01, 0.3),
                             ratio=(1.0, 1.0),
                             value=0,
                             inplace =True)      
])

val_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
race_train_dataset = TrainDataset(
    X_train_race, y_train_race,
    transform = train_transform
)

race_val_dataset = TrainDataset(
    X_val_race, y_val_race,
    transform = val_transform
)

# %%
train_batch_size = 32
val_batch_size = 32

race_train_loader = DataLoader(
    race_train_dataset,
    batch_size = train_batch_size,
    shuffle = True
) 

race_val_loader = DataLoader(
    race_val_dataset,
    batch_size = val_batch_size,
    shuffle = False
)

# %%
def evaluation(model,val_loader,criterion):
    model.eval()
    mpred, mlabel = [], []
    val_loss = 0.0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs,labels)
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs.data,1)
            mpred.extend(predicted.tolist())
            mlabel.extend(labels.tolist())
    
    accuracy = 100 * accuracy_score(mpred, mlabel)
    val_loss = val_loss / len(val_loader)
    return val_loss, accuracy

# %%
def save(filename, model):
    filename = "/kaggle/working/" + filename
    torch.save(model.state_dict(), filename)
    print("Saved model as", filename)

# %% [markdown]
# * **Race model**

# %%
race_model = InceptionResnetV1(pretrained='vggface2',
                              device=device,
                              classify= True,
                              num_classes=len(race_classes))

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(race_model.parameters(),
                             lr=1e-4)

# %% [markdown]
# * **Train race model**

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
max_epoch = 20
best_accuracy = 10
for epoch in range(max_epoch):
    race_model.train()
    mpred, mlabel = [], []
    running_loss = 0.0      
    
    print(f"Epoch {epoch + 1}: ", end='')
    for _ in tqdm(range(len(race_train_loader))):
        inputs, labels = next(iter(race_train_loader))
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = race_model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        running_loss += loss.item()
        
        loss.backward()
        optimizer.step()  
    
        
        _, predicted = torch.max(outputs.data, 1)
        mpred.extend(predicted.tolist())
        mlabel.extend(labels.tolist())

    epoch_accuracy = 100 * accuracy_score(mpred, mlabel)
    epoch_loss = running_loss / (len(race_train_loader))
    
    val_loss, val_accuracy = evaluation(race_model, race_val_loader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")
        
    if val_accuracy > best_accuracy:
        print("saving at epoch", epoch+1)
        best_accuracy = val_accuracy
        save("race_weight.pt", race_model)
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

# %% [markdown]
# * **Predict race model**

# %%
race_model.load_state_dict(torch.load("/kaggle/input/faceanalysisweights/race_weight73.pt"))
race_model.to(device)
# Out:
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=3, bias=True)
# )

# %%
reverse_race = ['Caucasian', 'Mongoloid', 'Negroid']

# %%
test_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
test_dataset = TestDataset(
    test_img_paths, img_names,
    transform = test_transform
)

# %%
test_batch_size = 64
test_loader = DataLoader(
    test_dataset,
    batch_size = test_batch_size,
    shuffle = False
)

# %%
race_submiss = {}
race_model.eval()
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = race_model(images)
        _, predicted = torch.max(outputs.data,1)
        for predict, name in zip(predicted, names):
            race_submiss[name[:-4]] = reverse_race[predict]

# %% [markdown]
# # **Gender model**

# %%
seed = 42
val_size = 0.3
is_shuffle = True
X_train_gender, X_val_gender, y_train_gender, y_val_gender = train_test_split(
    img_paths, gender_labels, 
    test_size = val_size, 
    random_state = seed,
    shuffle = is_shuffle
)

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(5),
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.75,
                             scale=(0.01, 0.3),
                             ratio=(1.0, 1.0),
                             value=0,
                             inplace =True)      
])

val_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
gender_train_dataset = TrainDataset(
    X_train_gender, y_train_gender,
    transform = train_transform
)

gender_val_dataset = TrainDataset(
    X_val_gender, y_val_gender,
    transform = val_transform
)

# %%
train_batch_size = 32
val_batch_size = 32

gender_train_loader = DataLoader(
    gender_train_dataset,
    batch_size = train_batch_size,
    shuffle = True
) 

gender_val_loader = DataLoader(
    gender_val_dataset,
    batch_size = val_batch_size,
    shuffle = False
)

# %%
def evaluation(model,val_loader,criterion):
    model.eval()
    mpred, mlabel = [], []
    val_loss = 0.0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs[:, 1],labels.float())
            val_loss += loss.item()
            
            _, predicted = torch.max(outputs.data,1)
            mpred.extend(predicted.tolist())
            mlabel.extend(labels.tolist())
    
    accuracy = 100 * accuracy_score(mpred, mlabel)
    val_loss = val_loss / len(val_loader)
    return val_loss, accuracy

# %%
def save(filename, model):
    filename = "/kaggle/working/" + filename
    torch.save(model.state_dict(), filename)
    print("Saved model as", filename)

# %% [markdown]
# * **Gender model**

# %%
gender_model = InceptionResnetV1(pretrained='vggface2',
                              device=device,
                              classify= True,
                              num_classes=len(gender_classes))

# %%
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(gender_model.parameters(),
                             lr=1e-4,
                             weight_decay=5e-7)

# %% [markdown]
# * **Train gender model**

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
max_epoch = 20
best_accuracy = 10
for epoch in range(max_epoch):
    gender_model.train()
    mpred, mlabel = [], []
    running_loss = 0.0      
    
    print(f"Epoch {epoch + 1}: ", end='')
    for _ in tqdm(range(len(gender_train_loader))):
        inputs, labels = next(iter(gender_train_loader))
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = gender_model(inputs)
        loss = criterion(outputs[:, 1], labels.float())
        optimizer.zero_grad()
        running_loss += loss.item()
        
        loss.backward()
        optimizer.step()  
    
        
        _, predicted = torch.max(outputs.data, 1)
        mpred.extend(predicted.tolist())
        mlabel.extend(labels.tolist())

    epoch_accuracy = 100 * accuracy_score(mpred, mlabel)
    epoch_loss = running_loss / (len(gender_train_loader))
    
    val_loss, val_accuracy = evaluation(gender_model, gender_val_loader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")
        
    if val_accuracy > best_accuracy:
        print("saving at epoch", epoch+1)
        best_accuracy = val_accuracy
        save("gender_weight.pt", gender_model)
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)

# %% [markdown]
# * **Plot gender model**

# %%
plt.plot(train_losses, label='train_losses')
plt.plot(val_losses, label='val_losses')
plt.legend()

# %%
plt.plot(train_accuracies, label='train_accuracy')
plt.plot(val_accuracies, label='val_accuracy')
plt.legend()

# %% [markdown]
# * **Predict gender model**

# %%
gender_model.load_state_dict(torch.load("/kaggle/input/faceanalysisweights/gender_weight73.pt"))
gender_model.to(device)
# Out:
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
reverse_gender = ['Male', 'Female']

# %%
test_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
test_dataset = TestDataset(
    test_img_paths, img_names,
    transform = test_transform
)

# %%
test_batch_size = 64
test_loader = DataLoader(
    test_dataset,
    batch_size = test_batch_size,
    shuffle = False
)

# %%
gender_submiss = {}
gender_model.eval()
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = gender_model(images)
        _, predicted = torch.max(outputs.data,1)
        for predict, name in zip(predicted, names):
            gender_submiss[name[:-4]] = reverse_gender[predict]

# %% [markdown]
# # **Emotion model**

# %%
seed = 42
val_size = 0.3
is_shuffle = True
X_train_emotion, X_val_emotion, y_train_emotion, y_val_emotion = train_test_split(
    img_paths,
    emotion_labels, 
    test_size = val_size, 
    random_state = seed,
    shuffle = is_shuffle
)

# %%
train_transform = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(5),
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
    transforms.RandomErasing(p=0.65,
                             scale=(0.01, 0.1),
                             ratio=(1.0, 1.0),
                             value=0,
                             inplace =True)    
])

val_transform = transforms.Compose([
        transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
emotion_train_dataset = TrainDataset(
    X_train_emotion, y_train_emotion,
    transform = train_transform
)

emotion_val_dataset = TrainDataset(
    X_val_emotion, y_val_emotion,
    transform = val_transform
)

# %%
train_batch_size = 64
val_batch_size = 64

emotion_train_loader = DataLoader(
    emotion_train_dataset,
    batch_size = train_batch_size,
    shuffle = True
) 

emotion_val_loader = DataLoader(
    emotion_val_dataset,
    batch_size = val_batch_size,
    shuffle = False
)

# %%
def evaluation(model,val_loader,mcriterion):
    model.eval()
    mpreds, mlabels = [], []
    mval_loss = 0.0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            mloss = mcriterion(outputs,labels)
            mval_loss += mloss.item()
            
            _, predicted = torch.max(outputs.data,1)
            mpreds.extend(predicted.tolist())
            mlabels.extend(labels.tolist())
    
    maccuracy = 100 * accuracy_score(mpreds, mlabels)
    mval_loss = mval_loss / len(val_loader)
    return mval_loss, maccuracy

# %%
def save(filename, model):
    filename = "/kaggle/working/" + filename
    torch.save(model.state_dict(), filename)
    print("Saved model as", filename)

# %% [markdown]
# * **Emotion model**

# %%
emotion_model = InceptionResnetV1(pretrained='vggface2',
                              device=device,
                              classify= True,
                              num_classes=len(emotion_classes))

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(emotion_model.parameters(),
                             lr=1e-4)

# %% [markdown]
# * **Train emotion model**

# %%
train_losses = []
train_accuracies = []
val_losses = []
val_accuracies = []
max_epoch = 10
best_accuracy = 10
for epoch in range(max_epoch):
    emotion_model.train()
    mpred, mlabel = [], []
    running_loss = 0.0      
    
    print(f"Epoch {epoch + 1}: ", end='')
    for _ in tqdm(range(len(emotion_train_loader))):
        inputs, labels = next(iter(emotion_train_loader))
        inputs, labels = inputs.to(device), labels.to(device)

        outputs = emotion_model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        running_loss += loss.item()
        
        loss.backward()
        optimizer.step()  
    
        
        _, predicted = torch.max(outputs.data, 1)
        mpred.extend(predicted.tolist())
        mlabel.extend(labels.tolist())

    epoch_accuracy = 100 * accuracy_score(mpred, mlabel)
    epoch_loss = running_loss / (len(emotion_train_loader))
    
    val_loss, val_accuracy = evaluation(emotion_model, emotion_val_loader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")
        
    if val_accuracy > best_accuracy:
        print("saving at epoch", epoch+1)
        best_accuracy = val_accuracy
        save("emotion_weight.pt", emotion_model)
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
# Out:
# Epoch 1:
# 100%|██████████| 168/168 [02:05<00:00,  1.34it/s]
# Epoch [1/30], Loss: 0.7352, Accuracy: 79.55%, Val Loss: 0.7606, Val Accuracy: 78.10%
# saving at epoch 1
# Saved model as /kaggle/working/emotion_weight.pt
# Epoch 2:
# 100%|██████████| 168/168 [01:38<00:00,  1.71it/s]
# Epoch [2/30], Loss: 0.5093, Accuracy: 84.39%, Val Loss: 0.5601, Val Accuracy: 83.63%
# saving at epoch 2
# Saved model as /kaggle/working/emotion_weight.pt
# Epoch 3:
# 100%|██████████| 168/168 [01:27<00:00,  1.91it/s]
# Epoch [3/30], Loss: 0.4787, Accuracy: 85.26%, Val Loss: 0.5718, Val Accuracy: 82.60%
# Epoch 4:
# 100%|██████████| 168/168 [01:23<00:00,  2.02it/s]
# Epoch [4/30], Loss: 0.3958, Accuracy: 86.97%, Val Loss: 0.5458, Val Accuracy: 82.97%
# Epoch 5:
# 100%|██████████| 168/168 [01:22<00:00,  2.03it/s]
# Epoch [5/30], Loss: 0.3582, Accuracy: 88.62%, Val Loss: 0.5559, Val Accuracy: 82.76%
# Epoch 6:
# 100%|██████████| 168/168 [01:22<00:00,  2.05it/s]
# Epoch [6/30], Loss: 0.3189, Accuracy: 89.28%, Val Loss: 0.6869, Val Accuracy: 79.86%
# Epoch 7:
# 100%|██████████| 168/168 [01:21<00:00,  2.06it/s]
# Epoch [7/30], Loss: 0.2880, Accuracy: 90.37%, Val Loss: 0.5831, Val Accuracy: 84.04%
# saving at epoch 7
# Saved model as /kaggle/working/emotion_weight.pt
# Epoch 8:
# 100%|██████████| 168/168 [01:21<00:00,  2.06it/s]
# Epoch [8/30], Loss: 0.2370, Accuracy: 92.02%, Val Loss: 0.5923, Val Accuracy: 83.71%
# Epoch 9:
# 100%|██████████| 168/168 [01:26<00:00,  1.94it/s]
# Epoch [9/30], Loss: 0.2202, Accuracy: 92.70%, Val Loss: 0.8022, Val Accuracy: 81.21%
# Epoch 10:
# 100%|██████████| 168/168 [01:26<00:00,  1.95it/s]
# Epoch [10/30], Loss: 0.2158, Accuracy: 92.75%, Val Loss: 0.6918, Val Accuracy: 83.37%
# Epoch 11:
# 100%|██████████| 168/168 [01:26<00:00,  1.95it/s]
# Epoch [11/30], Loss: 0.1745, Accuracy: 93.95%, Val Loss: 0.7194, Val Accuracy: 82.02%
# Epoch 12:
# 100%|██████████| 168/168 [01:25<00:00,  1.96it/s]
# Epoch [12/30], Loss: 0.1455, Accuracy: 95.09%, Val Loss: 0.6679, Val Accuracy: 83.15%
# Epoch 13:
# 100%|██████████| 168/168 [01:26<00:00,  1.94it/s]
# Epoch [13/30], Loss: 0.1370, Accuracy: 95.62%, Val Loss: 0.7589, Val Accuracy: 83.04%
# Epoch 14:
# 100%|██████████| 168/168 [01:24<00:00,  1.98it/s]
# Epoch [14/30], Loss: 0.1358, Accuracy: 95.43%, Val Loss: 0.6867, Val Accuracy: 83.58%
# Epoch 15:
# 100%|██████████| 168/168 [01:22<00:00,  2.04it/s]
# Epoch [15/30], Loss: 0.1170, Accuracy: 96.13%, Val Loss: 0.7026, Val Accuracy: 83.45%
# Epoch 16:
# 100%|██████████| 168/168 [01:22<00:00,  2.04it/s]
# Epoch [16/30], Loss: 0.1085, Accuracy: 96.50%, Val Loss: 0.7166, Val Accuracy: 83.65%
# Epoch 17:
# 100%|██████████| 168/168 [01:23<00:00,  2.01it/s]
# Epoch [17/30], Loss: 0.1090, Accuracy: 96.42%, Val Loss: 0.7944, Val Accuracy: 82.17%
# Epoch 18:
# 100%|██████████| 168/168 [01:21<00:00,  2.05it/s]
# Epoch [18/30], Loss: 0.1196, Accuracy: 95.97%, Val Loss: 0.6901, Val Accuracy: 82.45%
# Epoch 19:
# 100%|██████████| 168/168 [01:22<00:00,  2.04it/s]
# Epoch [19/30], Loss: 0.0981, Accuracy: 96.55%, Val Loss: 0.7557, Val Accuracy: 83.52%
# Epoch 20:
# 100%|██████████| 168/168 [01:21<00:00,  2.05it/s]
# Epoch [20/30], Loss: 0.0884, Accuracy: 96.95%, Val Loss: 0.7594, Val Accuracy: 82.91%
# Epoch 21:
# 100%|██████████| 168/168 [01:22<00:00,  2.05it/s]
# Epoch [21/30], Loss: 0.0803, Accuracy: 97.24%, Val Loss: 0.8146, Val Accuracy: 81.97%
# Epoch 22:
# 100%|██████████| 168/168 [01:22<00:00,  2.03it/s]
# Epoch [22/30], Loss: 0.0806, Accuracy: 97.41%, Val Loss: 0.8147, Val Accuracy: 83.39%
# Epoch 23:
# 100%|██████████| 168/168 [01:21<00:00,  2.05it/s]
# Epoch [23/30], Loss: 0.0878, Accuracy: 97.01%, Val Loss: 0.8270, Val Accuracy: 82.54%
# Epoch 24:
# 100%|██████████| 168/168 [01:22<00:00,  2.03it/s]
# Epoch [24/30], Loss: 0.0774, Accuracy: 97.30%, Val Loss: 0.8634, Val Accuracy: 83.71%
# Epoch 25:
# 100%|██████████| 168/168 [01:22<00:00,  2.04it/s]
# Epoch [25/30], Loss: 0.0851, Accuracy: 97.14%, Val Loss: 0.7775, Val Accuracy: 83.17%
# Epoch 26:
# 100%|██████████| 168/168 [01:22<00:00,  2.05it/s]
# Epoch [26/30], Loss: 0.0924, Accuracy: 96.69%, Val Loss: 0.9449, Val Accuracy: 83.43%
# Epoch 27:
# 100%|██████████| 168/168 [01:22<00:00,  2.04it/s]
# Epoch [27/30], Loss: 0.0816, Accuracy: 97.17%, Val Loss: 0.9251, Val Accuracy: 82.82%
# Epoch 28:
# 100%|██████████| 168/168 [01:23<00:00,  2.02it/s]
# Epoch [28/30], Loss: 0.0668, Accuracy: 97.55%, Val Loss: 0.9030, Val Accuracy: 83.41%
# Epoch 29:
# 100%|██████████| 168/168 [01:23<00:00,  2.02it/s]
# Epoch [29/30], Loss: 0.0637, Accuracy: 97.94%, Val Loss: 0.9041, Val Accuracy: 83.82%
# Epoch 30:
# 100%|██████████| 168/168 [01:22<00:00,  2.04it/s]
# Epoch [30/30], Loss: 0.0647, Accuracy: 97.94%, Val Loss: 1.0541, Val Accuracy: 83.50%

# %% [markdown]
# * **Predict emotion model**

# %%
emotion_model.load_state_dict(torch.load("/kaggle/input/emotion-weight-iceptionresnet/emotion_weight.pt"))
emotion_model.to(device)
# Out:
# InceptionResnetV1(
#   (conv2d_1a): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2a): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_2b): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (maxpool_3a): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2d_3b): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4a): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (conv2d_4b): BasicConv2d(
#     (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU()
#   )
#   (repeat_1): Sequential(
#     (0): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block35(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (branch2): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(256, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_6a): Mixed_6a(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(256, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_2): Sequential(
#     (0): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (5): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (6): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (7): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (8): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (9): Block17(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(896, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(256, 896, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (mixed_7a): Mixed_7a(
#     (branch0): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch2): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(896, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (branch3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (repeat_3): Sequential(
#     (0): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (1): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (2): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (3): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#     (4): Block8(
#       (branch0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (branch1): Sequential(
#         (0): BasicConv2d(
#           (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (1): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#         (2): BasicConv2d(
#           (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#           (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU()
#         )
#       )
#       (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#       (relu): ReLU()
#     )
#   )
#   (block8): Block8(
#     (branch0): BasicConv2d(
#       (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU()
#     )
#     (branch1): Sequential(
#       (0): BasicConv2d(
#         (conv): Conv2d(1792, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (1): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#       (2): BasicConv2d(
#         (conv): Conv2d(192, 192, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#         (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#       )
#     )
#     (conv2d): Conv2d(384, 1792, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (avgpool_1a): AdaptiveAvgPool2d(output_size=1)
#   (dropout): Dropout(p=0.6, inplace=False)
#   (last_linear): Linear(in_features=1792, out_features=512, bias=False)
#   (last_bn): BatchNorm1d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   (logits): Linear(in_features=512, out_features=7, bias=True)
# )

# %%
reverse_emotion = ['Neutral', 'Happiness', 'Anger', 'Surprise', 'Fear', 'Sadness', 'Disgust']

# %%
test_transform = transforms.Compose([
    transforms.Resize((160,160)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
test_dataset = TestDataset(
    test_img_paths, img_names,
    transform = test_transform
)

# %%
test_batch_size = 64
test_loader = DataLoader(
    test_dataset,
    batch_size = test_batch_size,
    shuffle = False
)

# %%
emotion_submiss = {}
emotion_model.eval()
with torch.no_grad():
    for images, names in test_loader:
        images = images.to(device)
        outputs = emotion_model(images)
        _, predicted = torch.max(outputs.data,1)
        for predict, name in zip(predicted, names):
            emotion_submiss[name[:-4]] = reverse_emotion[predict]

# %% [markdown]
# # **File Submission**

# %%
df1 = pd.read_csv("/kaggle/input/private-data-label80/data.csv")
df1.head()
# Out:
#    Unnamed: 0     file_name                   bbox
# 0           0   2435944.jpg   [795, 104, 669, 927]
# 1           1  13025961.jpg   [908, 281, 344, 359]
# 2           2  67202325.jpg  [1301, 197, 193, 247]
# 3           3   9800474.jpg   [934, 279, 285, 380]
# 4           4  66279849.jpg   [550, 298, 238, 328]

# %%
df1.insert(3, "image_id", 1)

# %%
with open("/kaggle/input/file-name-to-img-id-80/file_name_to_image_id_private.json") as f:
    anhxa = json.load(f)

# %%
for i in anhxa:
    df1.loc[df1["file_name"] == i, "image_id"]  = anhxa[i]

# %%
df1 = df1.drop(columns="Unnamed: 0")

# %%
for i in race_submiss:
    df1.loc[int(i),"race"] = race_submiss[i]
for i in age_submiss:
    df1.loc[int(i),"age"] = age_submiss[i]
for i in emotion_submiss:
    df1.loc[int(i),"emotion"] = emotion_submiss[i]
for i in gender_submiss:
    df1.loc[int(i),"gender"] = gender_submiss[i]
for i in skintone_submiss:
    df1.loc[int(i),"skintone"] = skintone_submiss[i]
for i in mask_submiss:
    df1.loc[int(i),"masked"] = mask_submiss[i]

# %%
df1.head()
# Out:
#       file_name                   bbox  image_id       race     age  \
# 0   2435944.jpg   [795, 104, 669, 927]      1074  Mongoloid  20-30s
# 1  13025961.jpg   [908, 281, 344, 359]       486  Mongoloid  20-30s
# 2  67202325.jpg  [1301, 197, 193, 247]      5843  Mongoloid  40-50s
# 3   9800474.jpg   [934, 279, 285, 380]     10824  Mongoloid  20-30s
# 4  66279849.jpg   [550, 298, 238, 328]      5670  Mongoloid  20-30s
#
#      emotion  gender skintone    masked
# 0  Happiness  Female    light  unmasked
# 1  Happiness  Female    light  unmasked
# 2  Happiness    Male    light  unmasked
# 3  Happiness  Female    light  unmasked
# 4    Neutral  Female    light  unmasked

# %%
df1.to_csv("answer.csv", index=False )

# %%
FileLink(r'answer.csv')
# Out:
# /kaggle/working/answer.csv
